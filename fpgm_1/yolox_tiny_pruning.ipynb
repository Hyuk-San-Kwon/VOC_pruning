# %%
import torch
import torch_pruning as tp
from yolox.models import yolox_tiny

model = yolox_tiny(num_classes=20,).cuda()
# 1. setup strategy (L1 Norm)
strategy = tp.strategy.L1Strategy() # or tp.strategy.RandomStrategy()

# %%
# 2. build dependency graph for resnet18
DG = tp.DependencyGraph()
DG.build_dependency(model, example_inputs=torch.randn(1,3,224,224).cuda())

# %%
temp = []
temp2 = list(model.state_dict().keys())
num_list = [0,1,2,3]
#print(temp2)
for i in range(len(temp2)):
        if 'bn' in temp2[i]:
            continue
        if 'weight' in temp2[i]:
            temp2[i] = temp2[i].replace('.weight','')
            temp2[i] = temp2[i].replace('2.0','2[0]')
            temp2[i] = temp2[i].replace('2.1','2[1]')
            temp2[i] = temp2[i].replace('3.0','3[0]')
            temp2[i] = temp2[i].replace('3.1','3[1]')
            temp2[i] = temp2[i].replace('4.0','4[0]')
            temp2[i] = temp2[i].replace('4.1','4[1]')
            temp2[i] = temp2[i].replace('5.0','5[0]')
            temp2[i] = temp2[i].replace('5.1','5[1]')
            temp2[i] = temp2[i].replace('5.2','5[2]')
            temp2[i] = temp2[i].replace('m.0','m[0]')
            temp2[i] = temp2[i].replace('m.1','m[1]')
            temp2[i] = temp2[i].replace('m.2','m[2]')
            temp.append(temp2[i])

print(temp)
# backbone 만 프루닝
# Out:
# ['backbone.backbone.stem.conv.conv', 'backbone.backbone.dark2[0].conv', 'backbone.backbone.dark2[1].conv1.conv', 'backbone.backbone.dark2[1].conv2.conv', 'backbone.backbone.dark2[1].conv3.conv', 'backbone.backbone.dark2[1].m[0].conv1.conv', 'backbone.backbone.dark2[1].m[0].conv2.conv', 'backbone.backbone.dark3[0].conv', 'backbone.backbone.dark3[1].conv1.conv', 'backbone.backbone.dark3[1].conv2.conv', 'backbone.backbone.dark3[1].conv3.conv', 'backbone.backbone.dark3[1].m[0].conv1.conv', 'backbone.backbone.dark3[1].m[0].conv2.conv', 'backbone.backbone.dark3[1].m[1].conv1.conv', 'backbone.backbone.dark3[1].m[1].conv2.conv', 'backbone.backbone.dark3[1].m[2].conv1.conv', 'backbone.backbone.dark3[1].m[2].conv2.conv', 'backbone.backbone.dark4[0].conv', 'backbone.backbone.dark4[1].conv1.conv', 'backbone.backbone.dark4[1].conv2.conv', 'backbone.backbone.dark4[1].conv3.conv', 'backbone.backbone.dark4[1].m[0].conv1.conv', 'backbone.backbone.dark4[1].m[0].conv2.conv', 'backbone.backbone.dark4[1].m[1].conv1.conv', 'backbone.backbone.dark4[1].m[1].conv2.conv', 'backbone.backbone.dark4[1].m[2].conv1.conv', 'backbone.backbone.dark4[1].m[2].conv2.conv', 'backbone.backbone.dark5[0].conv', 'backbone.backbone.dark5[1].conv1.conv', 'backbone.backbone.dark5[1].conv2.conv', 'backbone.backbone.dark5[2].conv1.conv', 'backbone.backbone.dark5[2].conv2.conv', 'backbone.backbone.dark5[2].conv3.conv', 'backbone.backbone.dark5[2].m[0].conv1.conv', 'backbone.backbone.dark5[2].m[0].conv2.conv', 'backbone.lateral_conv0.conv', 'backbone.C3_p4.conv1.conv', 'backbone.C3_p4.conv2.conv', 'backbone.C3_p4.conv3.conv', 'backbone.C3_p4.m[0].conv1.conv', 'backbone.C3_p4.m[0].conv2.conv', 'backbone.reduce_conv1.conv', 'backbone.C3_p3.conv1.conv', 'backbone.C3_p3.conv2.conv', 'backbone.C3_p3.conv3.conv', 'backbone.C3_p3.m[0].conv1.conv', 'backbone.C3_p3.m[0].conv2.conv', 'backbone.bu_conv2.conv', 'backbone.C3_n3.conv1.conv', 'backbone.C3_n3.conv2.conv', 'backbone.C3_n3.conv3.conv', 'backbone.C3_n3.m[0].conv1.conv', 'backbone.C3_n3.m[0].conv2.conv', 'backbone.bu_conv1.conv', 'backbone.C3_n4.conv1.conv', 'backbone.C3_n4.conv2.conv', 'backbone.C3_n4.conv3.conv', 'backbone.C3_n4.m[0].conv1.conv', 'backbone.C3_n4.m[0].conv2.conv', 'head.cls_convs.0.0.conv', 'head.cls_convs.0.1.conv', 'head.cls_convs.1.0.conv', 'head.cls_convs.1.1.conv', 'head.cls_convs.2[0].conv', 'head.cls_convs.2[1].conv', 'head.reg_convs.0.0.conv', 'head.reg_convs.0.1.conv', 'head.reg_convs.1.0.conv', 'head.reg_convs.1.1.conv', 'head.reg_convs.2[0].conv', 'head.reg_convs.2[1].conv', 'head.cls_preds.0', 'head.cls_preds.1', 'head.cls_preds.2', 'head.reg_preds.0', 'head.reg_preds.1', 'head.reg_preds.2', 'head.obj_preds.0', 'head.obj_preds.1', 'head.obj_preds.2', 'head.stems.0.conv', 'head.stems.1.conv', 'head.stems.2.conv']

# %%
print(model)
# Out:
# YOLOX(
#   (backbone): YOLOPAFPN(
#     (backbone): CSPDarknet(
#       (stem): Focus(
#         (conv): BaseConv(
#           (conv): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (dark2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(24, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark3): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(48, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark4): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark5): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): SPPBottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): ModuleList(
#             (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#             (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#             (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (upsample): Upsample(scale_factor=2.0, mode=nearest)
#     (lateral_conv0): BaseConv(
#       (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (reduce_conv1): BaseConv(
#       (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv2): BaseConv(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv1): BaseConv(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (head): YOLOXHead(
#     (cls_convs): ModuleList(
#       (0): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (reg_convs): ModuleList(
#       (0): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (cls_preds): ModuleList(
#       (0): Conv2d(96, 80, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 80, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 80, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (reg_preds): ModuleList(
#       (0): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (obj_preds): ModuleList(
#       (0): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stems): ModuleList(
#       (0): BaseConv(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): BaseConv(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): BaseConv(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (l1_loss): L1Loss()
#     (bcewithlog_loss): BCEWithLogitsLoss()
#     (iou_loss): IOUloss()
#   )
# )

# %%
temp = ['backbone.backbone.dark4[1].conv1.conv', 'backbone.backbone.dark4[1].conv2.conv',
'backbone.backbone.dark4[1].m[0].conv1.conv','backbone.backbone.dark4[1].m[0].conv2.conv', 'backbone.backbone.dark4[1].m[1].conv1.conv', 'backbone.backbone.dark4[1].m[1].conv2.conv', 'backbone.backbone.dark4[1].m[2].conv1.conv', 'backbone.backbone.dark4[1].m[2].conv2.conv'
,'backbone.backbone.dark5[1].conv1.conv', 'backbone.backbone.dark5[1].conv2.conv',
'backbone.backbone.dark5[2].conv1.conv', 'backbone.backbone.dark5[2].conv2.conv', 
'backbone.backbone.dark5[2].m[0].conv1.conv','backbone.backbone.dark5[2].m[0].conv2.conv' ]



temp = ['backbone.backbone.dark3[1].conv1.conv','backbone.backbone.dark3[1].conv2.conv',
'backbone.backbone.dark3[1].m[0].conv1.conv', 'backbone.backbone.dark3[1].m[1].conv1.conv', 
'backbone.backbone.dark3[1].m[2].conv1.conv',
'backbone.backbone.dark3[1].conv3.conv', ]
for i in range(len(temp)):
    layer = temp[i]
    pruning_idxs = strategy(eval(f"model.{layer}.weight"), amount=0.11) # or pruning_idxs=[2, 6, 9, ...]
    print(pruning_idxs)
    layer_split = layer
    pruning_plan = DG.get_pruning_plan(eval(f"model.{layer}"), tp.prune_conv_out_channel, idxs=pruning_idxs )
    print(pruning_plan)
    print(layer)

    # 4. execute this plan after checking (prune the model)
    #    if the plan prunes some channels to zero, 
    #    DG.check_pruning plan will return False.
    if DG.check_pruning_plan(pruning_plan):
        pruning_plan.exec()
        
temp = ['backbone.backbone.dark4[1].conv1.conv','backbone.backbone.dark4[1].conv2.conv',
'backbone.backbone.dark4[1].m[0].conv1.conv', 'backbone.backbone.dark4[1].m[1].conv1.conv', 'backbone.backbone.dark4[1].m[2].conv1.conv',
'backbone.backbone.dark4[1].conv3.conv', ]
for i in range(len(temp)):
    layer = temp[i]
    pruning_idxs = strategy(eval(f"model.{layer}.weight"), amount=0.105) # or pruning_idxs=[2, 6, 9, ...]
    print(pruning_idxs)
    layer_split = layer
    pruning_plan = DG.get_pruning_plan(eval(f"model.{layer}"), tp.prune_conv_out_channel, idxs=pruning_idxs )
    print(pruning_plan)
    print(layer)

    # 4. execute this plan after checking (prune the model)
    #    if the plan prunes some channels to zero, 
    #    DG.check_pruning plan will return False.
    if DG.check_pruning_plan(pruning_plan):
        pruning_plan.exec()     

temp = ['backbone.backbone.dark5[2].conv1.conv','backbone.backbone.dark5[2].conv2.conv',
'backbone.backbone.dark5[2].m[0].conv1.conv','backbone.backbone.dark5[2].m[0].conv2.conv',
'backbone.backbone.dark5[2].conv3.conv', ]
for i in range(len(temp)):
    layer = temp[i]
    pruning_idxs = strategy(eval(f"model.{layer}.weight"), amount=0.105) # or pruning_idxs=[2, 6, 9, ...]
    print(pruning_idxs)
    layer_split = layer
    pruning_plan = DG.get_pruning_plan(eval(f"model.{layer}"), tp.prune_conv_out_channel, idxs=pruning_idxs )
    print(pruning_plan)
    print(layer)

    # 4. execute this plan after checking (prune the model)
    #    if the plan prunes some channels to zero, 
    #    DG.check_pruning plan will return False.
    if DG.check_pruning_plan(pruning_plan):
        pruning_plan.exec()     

temp = ['backbone.lateral_conv0.conv', 'backbone.C3_p4.conv1.conv','backbone.C3_p4.conv2.conv',
'backbone.C3_p4.conv3.conv', 'backbone.C3_p4.m[0].conv1.conv', 'backbone.C3_p4.m[0].conv2.conv',
'backbone.reduce_conv1.conv',
'backbone.bu_conv2.conv', 
'backbone.bu_conv1.conv', ]
for i in range(len(temp)):
    layer = temp[i]
    pruning_idxs = strategy(eval(f"model.{layer}.weight"), amount=0.105) # or pruning_idxs=[2, 6, 9, ...]
    print(pruning_idxs)
    layer_split = layer
    pruning_plan = DG.get_pruning_plan(eval(f"model.{layer}"), tp.prune_conv_out_channel, idxs=pruning_idxs )
    print(pruning_plan)
    print(layer)

    # 4. execute this plan after checking (prune the model)
    #    if the plan prunes some channels to zero, 
    #    DG.check_pruning plan will return False.
    if DG.check_pruning_plan(pruning_plan):
        pruning_plan.exec()         


torch.save(model, 'model.pth')
# Out:
# [12, 18, 23, 43, 44]
# Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv1.conv (Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.conv1.conv (Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[12, 18, 23, 43, 44], metric={'#params': 480}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv1.conv (Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[12, 18, 23, 43, 44], metric={'#params': 10}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[12, 18, 23, 43, 44], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[12, 18, 23, 43, 44], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.0.conv1.conv (Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[12, 18, 23, 43, 44], metric={'#params': 240}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[12, 18, 23, 43, 44], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[12, 18, 23, 43, 44], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.1.conv1.conv (Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[12, 18, 23, 43, 44], metric={'#params': 240}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[12, 18, 23, 43, 44], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[12, 18, 23, 43, 44], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.2.conv1.conv (Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[12, 18, 23, 43, 44], metric={'#params': 240}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[12, 18, 23, 43, 44], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConcatPruner on _ConcatOp([0, 48, 96]), Index=[12, 18, 23, 43, 44], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 48, 96]) => ConvInChannelPruner on backbone.backbone.dark3.1.conv3.conv (Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[12, 18, 23, 43, 44], metric={'#params': 480}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark3.1.m.2.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[12, 18, 23, 43, 44], metric={'#params': 10}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.2.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.2.conv2.conv (Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[12, 18, 23, 43, 44], metric={'#params': 2160}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark3.1.m.1.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[12, 18, 23, 43, 44], metric={'#params': 10}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.1.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.1.conv2.conv (Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[12, 18, 23, 43, 44], metric={'#params': 2160}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark3.1.m.0.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[12, 18, 23, 43, 44], metric={'#params': 10}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.0.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.0.conv2.conv (Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[12, 18, 23, 43, 44], metric={'#params': 2160}]
#
# Metric Sum: {'#params': 8200}
# --------------------------------
#
# backbone.backbone.dark3[1].conv1.conv
# [0, 18, 28, 37, 47]
# Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv2.conv (Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.conv2.conv (Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 18, 28, 37, 47], metric={'#params': 480}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv2.conv (Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 18, 28, 37, 47], metric={'#params': 10}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 18, 28, 37, 47], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 43, 91]), Index=[43, 61, 71, 80, 90], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 43, 91]) => ConvInChannelPruner on backbone.backbone.dark3.1.conv3.conv (Conv2d(91, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[43, 61, 71, 80, 90], metric={'#params': 480}]
#
# Metric Sum: {'#params': 970}
# --------------------------------
#
# backbone.backbone.dark3[1].conv2.conv
# [7, 15, 20, 28, 41]
# Conv2d(43, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.0.conv1.conv (Conv2d(43, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.0.conv1.conv (Conv2d(43, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[7, 15, 20, 28, 41], metric={'#params': 215}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.0.conv1.conv (Conv2d(43, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.m.0.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[7, 15, 20, 28, 41], metric={'#params': 10}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.0.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[7, 15, 20, 28, 41], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.0.conv2.conv (Conv2d(48, 43, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[7, 15, 20, 28, 41], metric={'#params': 1935}]
#
# Metric Sum: {'#params': 2160}
# --------------------------------
#
# backbone.backbone.dark3[1].m[0].conv1.conv
# [6, 8, 33, 35, 44]
# Conv2d(43, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.1.conv1.conv (Conv2d(43, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.1.conv1.conv (Conv2d(43, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[6, 8, 33, 35, 44], metric={'#params': 215}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.1.conv1.conv (Conv2d(43, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.m.1.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[6, 8, 33, 35, 44], metric={'#params': 10}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.1.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[6, 8, 33, 35, 44], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.1.conv2.conv (Conv2d(48, 43, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[6, 8, 33, 35, 44], metric={'#params': 1935}]
#
# Metric Sum: {'#params': 2160}
# --------------------------------
#
# backbone.backbone.dark3[1].m[1].conv1.conv
# [4, 10, 22, 41, 43]
# Conv2d(43, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.2.conv1.conv (Conv2d(43, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.2.conv1.conv (Conv2d(43, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 10, 22, 41, 43], metric={'#params': 215}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.2.conv1.conv (Conv2d(43, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.m.2.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[4, 10, 22, 41, 43], metric={'#params': 10}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.2.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[4, 10, 22, 41, 43], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.2.conv2.conv (Conv2d(48, 43, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[4, 10, 22, 41, 43], metric={'#params': 1935}]
#
# Metric Sum: {'#params': 2160}
# --------------------------------
#
# backbone.backbone.dark3[1].m[2].conv1.conv
# [6, 7, 10, 11, 22, 29, 54, 85, 87, 94]
# Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv3.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.conv3.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[6, 7, 10, 11, 22, 29, 54, 85, 87, 94], metric={'#params': 860}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv3.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.conv3.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[6, 7, 10, 11, 22, 29, 54, 85, 87, 94], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.conv3.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[6, 7, 10, 11, 22, 29, 54, 85, 87, 94], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark4.0.conv (Conv2d(96, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), Index=[6, 7, 10, 11, 22, 29, 54, 85, 87, 94], metric={'#params': 17280}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 96, 192]), Index=[102, 103, 106, 107, 118, 125, 150, 181, 183, 190], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 192]) => ConvInChannelPruner on backbone.C3_p3.conv2.conv (Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[102, 103, 106, 107, 118, 125, 150, 181, 183, 190], metric={'#params': 480}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 192]) => ConvInChannelPruner on backbone.C3_p3.conv1.conv (Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[102, 103, 106, 107, 118, 125, 150, 181, 183, 190], metric={'#params': 480}]
#
# Metric Sum: {'#params': 19120}
# --------------------------------
#
# backbone.backbone.dark3[1].conv3.conv
# [1, 12, 17, 28, 32, 36, 39, 54, 61, 77]
# Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv1.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.conv1.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={'#params': 1920}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv1.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.0.conv1.conv (Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={'#params': 960}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.1.conv1.conv (Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={'#params': 960}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.2.conv1.conv (Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={'#params': 960}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConcatPruner on _ConcatOp([0, 96, 192]), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 192]) => ConvInChannelPruner on backbone.backbone.dark4.1.conv3.conv (Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={'#params': 1920}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark4.1.m.2.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.2.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.2.conv2.conv (Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={'#params': 8640}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark4.1.m.1.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.1.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.1.conv2.conv (Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={'#params': 8640}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark4.1.m.0.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.0.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.0.conv2.conv (Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[1, 12, 17, 28, 32, 36, 39, 54, 61, 77], metric={'#params': 8640}]
#
# Metric Sum: {'#params': 32720}
# --------------------------------
#
# backbone.backbone.dark4[1].conv1.conv
# [20, 29, 30, 48, 49, 51, 62, 64, 85, 91]
# Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv2.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.conv2.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[20, 29, 30, 48, 49, 51, 62, 64, 85, 91], metric={'#params': 1920}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv2.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[20, 29, 30, 48, 49, 51, 62, 64, 85, 91], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[20, 29, 30, 48, 49, 51, 62, 64, 85, 91], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 86, 182]), Index=[106, 115, 116, 134, 135, 137, 148, 150, 171, 177], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 86, 182]) => ConvInChannelPruner on backbone.backbone.dark4.1.conv3.conv (Conv2d(182, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[106, 115, 116, 134, 135, 137, 148, 150, 171, 177], metric={'#params': 1920}]
#
# Metric Sum: {'#params': 3860}
# --------------------------------
#
# backbone.backbone.dark4[1].conv2.conv
# [9, 22, 29, 31, 52, 56, 64, 82, 84, 90]
# Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.0.conv1.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.0.conv1.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[9, 22, 29, 31, 52, 56, 64, 82, 84, 90], metric={'#params': 860}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.0.conv1.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.m.0.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[9, 22, 29, 31, 52, 56, 64, 82, 84, 90], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.0.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[9, 22, 29, 31, 52, 56, 64, 82, 84, 90], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.0.conv2.conv (Conv2d(96, 86, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[9, 22, 29, 31, 52, 56, 64, 82, 84, 90], metric={'#params': 7740}]
#
# Metric Sum: {'#params': 8620}
# --------------------------------
#
# backbone.backbone.dark4[1].m[0].conv1.conv
# [7, 40, 45, 49, 73, 78, 79, 84, 93, 94]
# Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.1.conv1.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.1.conv1.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[7, 40, 45, 49, 73, 78, 79, 84, 93, 94], metric={'#params': 860}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.1.conv1.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.m.1.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[7, 40, 45, 49, 73, 78, 79, 84, 93, 94], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.1.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[7, 40, 45, 49, 73, 78, 79, 84, 93, 94], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.1.conv2.conv (Conv2d(96, 86, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[7, 40, 45, 49, 73, 78, 79, 84, 93, 94], metric={'#params': 7740}]
#
# Metric Sum: {'#params': 8620}
# --------------------------------
#
# backbone.backbone.dark4[1].m[1].conv1.conv
# [9, 44, 49, 52, 55, 62, 68, 69, 76, 94]
# Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.2.conv1.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.2.conv1.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[9, 44, 49, 52, 55, 62, 68, 69, 76, 94], metric={'#params': 860}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.2.conv1.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.m.2.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[9, 44, 49, 52, 55, 62, 68, 69, 76, 94], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.2.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[9, 44, 49, 52, 55, 62, 68, 69, 76, 94], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.2.conv2.conv (Conv2d(96, 86, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[9, 44, 49, 52, 55, 62, 68, 69, 76, 94], metric={'#params': 7740}]
#
# Metric Sum: {'#params': 8620}
# --------------------------------
#
# backbone.backbone.dark4[1].m[2].conv1.conv
# [0, 1, 3, 4, 12, 22, 35, 38, 51, 64, 66, 84, 109, 110, 131, 135, 147, 157, 168, 179]
# Conv2d(172, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv3.conv (Conv2d(172, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.conv3.conv (Conv2d(172, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 1, 3, 4, 12, 22, 35, 38, 51, 64, 66, 84, 109, 110, 131, 135, 147, 157, 168, 179], metric={'#params': 3440}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv3.conv (Conv2d(172, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.conv3.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 1, 3, 4, 12, 22, 35, 38, 51, 64, 66, 84, 109, 110, 131, 135, 147, 157, 168, 179], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.conv3.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 1, 3, 4, 12, 22, 35, 38, 51, 64, 66, 84, 109, 110, 131, 135, 147, 157, 168, 179], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark5.0.conv (Conv2d(192, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), Index=[0, 1, 3, 4, 12, 22, 35, 38, 51, 64, 66, 84, 109, 110, 131, 135, 147, 157, 168, 179], metric={'#params': 69120}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 192, 384]), Index=[192, 193, 195, 196, 204, 214, 227, 230, 243, 256, 258, 276, 301, 302, 323, 327, 339, 349, 360, 371], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 384]) => ConvInChannelPruner on backbone.C3_p4.conv2.conv (Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[192, 193, 195, 196, 204, 214, 227, 230, 243, 256, 258, 276, 301, 302, 323, 327, 339, 349, 360, 371], metric={'#params': 1920}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 384]) => ConvInChannelPruner on backbone.C3_p4.conv1.conv (Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[192, 193, 195, 196, 204, 214, 227, 230, 243, 256, 258, 276, 301, 302, 323, 327, 339, 349, 360, 371], metric={'#params': 1920}]
#
# Metric Sum: {'#params': 76440}
# --------------------------------
#
# backbone.backbone.dark4[1].conv3.conv
# [2, 9, 11, 61, 67, 69, 74, 83, 85, 96, 98, 99, 100, 110, 121, 135, 156, 157, 170, 176]
# Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv1.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark5.2.conv1.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[2, 9, 11, 61, 67, 69, 74, 83, 85, 96, 98, 99, 100, 110, 121, 135, 156, 157, 170, 176], metric={'#params': 7680}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv1.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark5.2.conv1.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[2, 9, 11, 61, 67, 69, 74, 83, 85, 96, 98, 99, 100, 110, 121, 135, 156, 157, 170, 176], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark5.2.conv1.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[2, 9, 11, 61, 67, 69, 74, 83, 85, 96, 98, 99, 100, 110, 121, 135, 156, 157, 170, 176], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark5.2.m.0.conv1.conv (Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[2, 9, 11, 61, 67, 69, 74, 83, 85, 96, 98, 99, 100, 110, 121, 135, 156, 157, 170, 176], metric={'#params': 3840}]
#
# Metric Sum: {'#params': 11560}
# --------------------------------
#
# backbone.backbone.dark5[2].conv1.conv
# [4, 16, 27, 41, 51, 60, 65, 78, 84, 115, 118, 135, 149, 159, 163, 170, 171, 172, 176, 178]
# Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv2.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark5.2.conv2.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 16, 27, 41, 51, 60, 65, 78, 84, 115, 118, 135, 149, 159, 163, 170, 171, 172, 176, 178], metric={'#params': 7680}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv2.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark5.2.conv2.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[4, 16, 27, 41, 51, 60, 65, 78, 84, 115, 118, 135, 149, 159, 163, 170, 171, 172, 176, 178], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark5.2.conv2.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[4, 16, 27, 41, 51, 60, 65, 78, 84, 115, 118, 135, 149, 159, 163, 170, 171, 172, 176, 178], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 192, 384]), Index=[196, 208, 219, 233, 243, 252, 257, 270, 276, 307, 310, 327, 341, 351, 355, 362, 363, 364, 368, 370], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 384]) => ConvInChannelPruner on backbone.backbone.dark5.2.conv3.conv (Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[196, 208, 219, 233, 243, 252, 257, 270, 276, 307, 310, 327, 341, 351, 355, 362, 363, 364, 368, 370], metric={'#params': 7680}]
#
# Metric Sum: {'#params': 15400}
# --------------------------------
#
# backbone.backbone.dark5[2].conv2.conv
# [1, 7, 19, 21, 25, 30, 32, 33, 54, 62, 68, 80, 85, 95, 110, 112, 127, 150, 178, 185]
# Conv2d(172, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv1.conv (Conv2d(172, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv1.conv (Conv2d(172, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 7, 19, 21, 25, 30, 32, 33, 54, 62, 68, 80, 85, 95, 110, 112, 127, 150, 178, 185], metric={'#params': 3440}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv1.conv (Conv2d(172, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark5.2.m.0.conv1.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 7, 19, 21, 25, 30, 32, 33, 54, 62, 68, 80, 85, 95, 110, 112, 127, 150, 178, 185], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark5.2.m.0.conv1.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 7, 19, 21, 25, 30, 32, 33, 54, 62, 68, 80, 85, 95, 110, 112, 127, 150, 178, 185], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark5.2.m.0.conv2.conv (Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[1, 7, 19, 21, 25, 30, 32, 33, 54, 62, 68, 80, 85, 95, 110, 112, 127, 150, 178, 185], metric={'#params': 34560}]
#
# Metric Sum: {'#params': 38040}
# --------------------------------
#
# backbone.backbone.dark5[2].m[0].conv1.conv
# [1, 8, 12, 26, 32, 33, 50, 63, 73, 74, 76, 107, 110, 127, 141, 142, 158, 161, 166, 185]
# Conv2d(172, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv2.conv (Conv2d(172, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv2.conv (Conv2d(172, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[1, 8, 12, 26, 32, 33, 50, 63, 73, 74, 76, 107, 110, 127, 141, 142, 158, 161, 166, 185], metric={'#params': 30960}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv2.conv (Conv2d(172, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark5.2.m.0.conv2.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 8, 12, 26, 32, 33, 50, 63, 73, 74, 76, 107, 110, 127, 141, 142, 158, 161, 166, 185], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark5.2.m.0.conv2.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 8, 12, 26, 32, 33, 50, 63, 73, 74, 76, 107, 110, 127, 141, 142, 158, 161, 166, 185], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 192, 364]), Index=[1, 8, 12, 26, 32, 33, 50, 63, 73, 74, 76, 107, 110, 127, 141, 142, 158, 161, 166, 185], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 364]) => ConvInChannelPruner on backbone.backbone.dark5.2.conv3.conv (Conv2d(364, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 8, 12, 26, 32, 33, 50, 63, 73, 74, 76, 107, 110, 127, 141, 142, 158, 161, 166, 185], metric={'#params': 7680}]
#
# Metric Sum: {'#params': 38680}
# --------------------------------
#
# backbone.backbone.dark5[2].m[0].conv2.conv
# [15, 20, 25, 31, 44, 52, 60, 61, 73, 89, 110, 115, 117, 122, 134, 152, 158, 178, 185, 188, 204, 209, 212, 229, 230, 239, 240, 241, 249, 250, 256, 266, 268, 279, 295, 308, 324, 336, 343, 356]
# Conv2d(344, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv3.conv (Conv2d(344, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark5.2.conv3.conv (Conv2d(344, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[15, 20, 25, 31, 44, 52, 60, 61, 73, 89, 110, 115, 117, 122, 134, 152, 158, 178, 185, 188, 204, 209, 212, 229, 230, 239, 240, 241, 249, 250, 256, 266, 268, 279, 295, 308, 324, 336, 343, 356], metric={'#params': 13760}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv3.conv (Conv2d(344, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark5.2.conv3.bn (BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[15, 20, 25, 31, 44, 52, 60, 61, 73, 89, 110, 115, 117, 122, 134, 152, 158, 178, 185, 188, 204, 209, 212, 229, 230, 239, 240, 241, 249, 250, 256, 266, 268, 279, 295, 308, 324, 336, 343, 356], metric={'#params': 80}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark5.2.conv3.bn (BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[15, 20, 25, 31, 44, 52, 60, 61, 73, 89, 110, 115, 117, 122, 134, 152, 158, 178, 185, 188, 204, 209, 212, 229, 230, 239, 240, 241, 249, 250, 256, 266, 268, 279, 295, 308, 324, 336, 343, 356], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.lateral_conv0.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[15, 20, 25, 31, 44, 52, 60, 61, 73, 89, 110, 115, 117, 122, 134, 152, 158, 178, 185, 188, 204, 209, 212, 229, 230, 239, 240, 241, 249, 250, 256, 266, 268, 279, 295, 308, 324, 336, 343, 356], metric={'#params': 7680}]
#
# Metric Sum: {'#params': 21520}
# --------------------------------
#
# backbone.backbone.dark5[2].conv3.conv
# [0, 4, 12, 13, 19, 48, 62, 68, 73, 75, 79, 83, 92, 120, 122, 124, 143, 152, 155, 177]
# Conv2d(344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.lateral_conv0.conv (Conv2d(344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.lateral_conv0.conv (Conv2d(344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 4, 12, 13, 19, 48, 62, 68, 73, 75, 79, 83, 92, 120, 122, 124, 143, 152, 155, 177], metric={'#params': 6880}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.lateral_conv0.conv (Conv2d(344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.lateral_conv0.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 4, 12, 13, 19, 48, 62, 68, 73, 75, 79, 83, 92, 120, 122, 124, 143, 152, 155, 177], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.lateral_conv0.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 4, 12, 13, 19, 48, 62, 68, 73, 75, 79, 83, 92, 120, 122, 124, 143, 152, 155, 177], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 192, 384]), Index=[192, 196, 204, 205, 211, 240, 254, 260, 265, 267, 271, 275, 284, 312, 314, 316, 335, 344, 347, 369], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ElementWiseOpPruner on _ElementWiseOp(UpsampleNearest2DBackward1), Index=[0, 4, 12, 13, 19, 48, 62, 68, 73, 75, 79, 83, 92, 120, 122, 124, 143, 152, 155, 177], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(UpsampleNearest2DBackward1) => ConcatPruner on _ConcatOp([0, 192, 364]), Index=[0, 4, 12, 13, 19, 48, 62, 68, 73, 75, 79, 83, 92, 120, 122, 124, 143, 152, 155, 177], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 364]) => ConvInChannelPruner on backbone.C3_p4.conv2.conv (Conv2d(364, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 4, 12, 13, 19, 48, 62, 68, 73, 75, 79, 83, 92, 120, 122, 124, 143, 152, 155, 177], metric={'#params': 1920}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 364]) => ConvInChannelPruner on backbone.C3_p4.conv1.conv (Conv2d(364, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 4, 12, 13, 19, 48, 62, 68, 73, 75, 79, 83, 92, 120, 122, 124, 143, 152, 155, 177], metric={'#params': 1920}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 384]) => ConvInChannelPruner on backbone.C3_n4.conv2.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[192, 196, 204, 205, 211, 240, 254, 260, 265, 267, 271, 275, 284, 312, 314, 316, 335, 344, 347, 369], metric={'#params': 3840}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 384]) => ConvInChannelPruner on backbone.C3_n4.conv1.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[192, 196, 204, 205, 211, 240, 254, 260, 265, 267, 271, 275, 284, 312, 314, 316, 335, 344, 347, 369], metric={'#params': 3840}]
#
# Metric Sum: {'#params': 18440}
# --------------------------------
#
# backbone.lateral_conv0.conv
# [3, 5, 7, 8, 11, 23, 26, 39, 76, 90]
# Conv2d(344, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.conv1.conv (Conv2d(344, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.C3_p4.conv1.conv (Conv2d(344, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[3, 5, 7, 8, 11, 23, 26, 39, 76, 90], metric={'#params': 3440}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.conv1.conv (Conv2d(344, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.C3_p4.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[3, 5, 7, 8, 11, 23, 26, 39, 76, 90], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.C3_p4.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[3, 5, 7, 8, 11, 23, 26, 39, 76, 90], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.C3_p4.m.0.conv1.conv (Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[3, 5, 7, 8, 11, 23, 26, 39, 76, 90], metric={'#params': 960}]
#
# Metric Sum: {'#params': 4420}
# --------------------------------
#
# backbone.C3_p4.conv1.conv
# [0, 1, 4, 25, 43, 47, 57, 74, 78, 83]
# Conv2d(344, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.conv2.conv (Conv2d(344, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.C3_p4.conv2.conv (Conv2d(344, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 1, 4, 25, 43, 47, 57, 74, 78, 83], metric={'#params': 3440}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.conv2.conv (Conv2d(344, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.C3_p4.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 1, 4, 25, 43, 47, 57, 74, 78, 83], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.C3_p4.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 1, 4, 25, 43, 47, 57, 74, 78, 83], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 96, 192]), Index=[96, 97, 100, 121, 139, 143, 153, 170, 174, 179], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 192]) => ConvInChannelPruner on backbone.C3_p4.conv3.conv (Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[96, 97, 100, 121, 139, 143, 153, 170, 174, 179], metric={'#params': 1920}]
#
# Metric Sum: {'#params': 5380}
# --------------------------------
#
# backbone.C3_p4.conv2.conv
# [11, 22, 28, 32, 39, 54, 69, 77, 89, 100, 116, 124, 132, 149, 158, 165, 168, 180, 186, 190]
# Conv2d(182, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.conv3.conv (Conv2d(182, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.C3_p4.conv3.conv (Conv2d(182, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[11, 22, 28, 32, 39, 54, 69, 77, 89, 100, 116, 124, 132, 149, 158, 165, 168, 180, 186, 190], metric={'#params': 3640}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.conv3.conv (Conv2d(182, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.C3_p4.conv3.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[11, 22, 28, 32, 39, 54, 69, 77, 89, 100, 116, 124, 132, 149, 158, 165, 168, 180, 186, 190], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.C3_p4.conv3.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[11, 22, 28, 32, 39, 54, 69, 77, 89, 100, 116, 124, 132, 149, 158, 165, 168, 180, 186, 190], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.reduce_conv1.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[11, 22, 28, 32, 39, 54, 69, 77, 89, 100, 116, 124, 132, 149, 158, 165, 168, 180, 186, 190], metric={'#params': 1920}]
#
# Metric Sum: {'#params': 5600}
# --------------------------------
#
# backbone.C3_p4.conv3.conv
# [17, 23, 32, 45, 60, 67, 71, 80, 83, 93]
# Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.m.0.conv1.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.C3_p4.m.0.conv1.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[17, 23, 32, 45, 60, 67, 71, 80, 83, 93], metric={'#params': 860}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.m.0.conv1.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.C3_p4.m.0.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[17, 23, 32, 45, 60, 67, 71, 80, 83, 93], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.C3_p4.m.0.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[17, 23, 32, 45, 60, 67, 71, 80, 83, 93], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.C3_p4.m.0.conv2.conv (Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[17, 23, 32, 45, 60, 67, 71, 80, 83, 93], metric={'#params': 8640}]
#
# Metric Sum: {'#params': 9520}
# --------------------------------
#
# backbone.C3_p4.m[0].conv1.conv
# [15, 24, 35, 39, 48, 52, 64, 80, 89, 90]
# Conv2d(86, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.m.0.conv2.conv (Conv2d(86, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.C3_p4.m.0.conv2.conv (Conv2d(86, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[15, 24, 35, 39, 48, 52, 64, 80, 89, 90], metric={'#params': 7740}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.m.0.conv2.conv (Conv2d(86, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => BatchnormPruner on backbone.C3_p4.m.0.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[15, 24, 35, 39, 48, 52, 64, 80, 89, 90], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.C3_p4.m.0.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[15, 24, 35, 39, 48, 52, 64, 80, 89, 90], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 96, 182]), Index=[15, 24, 35, 39, 48, 52, 64, 80, 89, 90], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 182]) => ConvInChannelPruner on backbone.C3_p4.conv3.conv (Conv2d(182, 172, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[15, 24, 35, 39, 48, 52, 64, 80, 89, 90], metric={'#params': 1720}]
#
# Metric Sum: {'#params': 9480}
# --------------------------------
#
# backbone.C3_p4.m[0].conv2.conv
# [28, 37, 45, 51, 63, 64, 71, 74, 86, 87]
# Conv2d(172, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.reduce_conv1.conv (Conv2d(172, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.reduce_conv1.conv (Conv2d(172, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[28, 37, 45, 51, 63, 64, 71, 74, 86, 87], metric={'#params': 1720}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.reduce_conv1.conv (Conv2d(172, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.reduce_conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[28, 37, 45, 51, 63, 64, 71, 74, 86, 87], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.reduce_conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[28, 37, 45, 51, 63, 64, 71, 74, 86, 87], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 96, 192]), Index=[124, 133, 141, 147, 159, 160, 167, 170, 182, 183], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ElementWiseOpPruner on _ElementWiseOp(UpsampleNearest2DBackward1), Index=[28, 37, 45, 51, 63, 64, 71, 74, 86, 87], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(UpsampleNearest2DBackward1) => ConcatPruner on _ConcatOp([0, 96, 182]), Index=[28, 37, 45, 51, 63, 64, 71, 74, 86, 87], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 182]) => ConvInChannelPruner on backbone.C3_p3.conv2.conv (Conv2d(182, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[28, 37, 45, 51, 63, 64, 71, 74, 86, 87], metric={'#params': 480}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 182]) => ConvInChannelPruner on backbone.C3_p3.conv1.conv (Conv2d(182, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[28, 37, 45, 51, 63, 64, 71, 74, 86, 87], metric={'#params': 480}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 192]) => ConvInChannelPruner on backbone.C3_n3.conv2.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[124, 133, 141, 147, 159, 160, 167, 170, 182, 183], metric={'#params': 960}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 192]) => ConvInChannelPruner on backbone.C3_n3.conv1.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[124, 133, 141, 147, 159, 160, 167, 170, 182, 183], metric={'#params': 960}]
#
# Metric Sum: {'#params': 4620}
# --------------------------------
#
# backbone.reduce_conv1.conv
# [9, 14, 17, 21, 24, 32, 69, 70, 72, 83]
# Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.bu_conv2.conv (Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.bu_conv2.conv (Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), Index=[9, 14, 17, 21, 24, 32, 69, 70, 72, 83], metric={'#params': 8640}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.bu_conv2.conv (Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => BatchnormPruner on backbone.bu_conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[9, 14, 17, 21, 24, 32, 69, 70, 72, 83], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.bu_conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[9, 14, 17, 21, 24, 32, 69, 70, 72, 83], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 96, 182]), Index=[9, 14, 17, 21, 24, 32, 69, 70, 72, 83], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 182]) => ConvInChannelPruner on backbone.C3_n3.conv2.conv (Conv2d(182, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[9, 14, 17, 21, 24, 32, 69, 70, 72, 83], metric={'#params': 960}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 182]) => ConvInChannelPruner on backbone.C3_n3.conv1.conv (Conv2d(182, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[9, 14, 17, 21, 24, 32, 69, 70, 72, 83], metric={'#params': 960}]
#
# Metric Sum: {'#params': 10580}
# --------------------------------
#
# backbone.bu_conv2.conv
# [14, 25, 27, 31, 33, 46, 68, 82, 103, 104, 113, 145, 149, 154, 163, 164, 167, 170, 179, 189]
# Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.bu_conv1.conv (Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.bu_conv1.conv (Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), Index=[14, 25, 27, 31, 33, 46, 68, 82, 103, 104, 113, 145, 149, 154, 163, 164, 167, 170, 179, 189], metric={'#params': 34560}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.bu_conv1.conv (Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => BatchnormPruner on backbone.bu_conv1.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[14, 25, 27, 31, 33, 46, 68, 82, 103, 104, 113, 145, 149, 154, 163, 164, 167, 170, 179, 189], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.bu_conv1.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[14, 25, 27, 31, 33, 46, 68, 82, 103, 104, 113, 145, 149, 154, 163, 164, 167, 170, 179, 189], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 192, 364]), Index=[14, 25, 27, 31, 33, 46, 68, 82, 103, 104, 113, 145, 149, 154, 163, 164, 167, 170, 179, 189], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 364]) => ConvInChannelPruner on backbone.C3_n4.conv2.conv (Conv2d(364, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[14, 25, 27, 31, 33, 46, 68, 82, 103, 104, 113, 145, 149, 154, 163, 164, 167, 170, 179, 189], metric={'#params': 3840}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 364]) => ConvInChannelPruner on backbone.C3_n4.conv1.conv (Conv2d(364, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[14, 25, 27, 31, 33, 46, 68, 82, 103, 104, 113, 145, 149, 154, 163, 164, 167, 170, 179, 189], metric={'#params': 3840}]
#
# Metric Sum: {'#params': 42280}
# --------------------------------
#
# backbone.bu_conv1.conv

# %%
print(model)
# Out:
# YOLOX(
#   (backbone): YOLOPAFPN(
#     (backbone): CSPDarknet(
#       (stem): Focus(
#         (conv): BaseConv(
#           (conv): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (dark2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(24, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark3): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(48, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(96, 43, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(43, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(96, 43, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(43, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(86, 86, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(43, 43, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(43, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(43, 43, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(43, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(43, 43, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(43, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(43, 43, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(43, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(43, 43, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(43, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(43, 43, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(43, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark4): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(86, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(192, 86, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(192, 86, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(172, 172, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(172, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(86, 86, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(86, 86, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(86, 86, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(86, 86, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(86, 86, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(86, 86, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark5): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(172, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): SPPBottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): ModuleList(
#             (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#             (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#             (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(384, 172, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(172, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(384, 172, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(172, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(344, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(344, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(172, 172, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(172, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(172, 172, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(172, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (upsample): Upsample(scale_factor=2.0, mode=nearest)
#     (lateral_conv0): BaseConv(
#       (conv): Conv2d(344, 172, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(172, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(344, 86, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(344, 86, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(172, 172, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(172, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(86, 86, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(86, 86, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (reduce_conv1): BaseConv(
#       (conv): Conv2d(172, 86, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(172, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(172, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv2): BaseConv(
#       (conv): Conv2d(96, 86, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(86, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(172, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(172, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv1): BaseConv(
#       (conv): Conv2d(192, 172, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(172, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (head): YOLOXHead(
#     (cls_convs): ModuleList(
#       (0): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (reg_convs): ModuleList(
#       (0): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (cls_preds): ModuleList(
#       (0): Conv2d(96, 80, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 80, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 80, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (reg_preds): ModuleList(
#       (0): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (obj_preds): ModuleList(
#       (0): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stems): ModuleList(
#       (0): BaseConv(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): BaseConv(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): BaseConv(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (l1_loss): L1Loss()
#     (bcewithlog_loss): BCEWithLogitsLoss()
#     (iou_loss): IOUloss()
#   )
# )
