# %%
import torch
import torch_pruning as tp
from yolox.models import create_yolox_model

model = create_yolox_model(num_classes=20,name = 'yolox_custom',  
exp_path = '/workspace/tensorrt/YOLOX/exps/default/custom/original/yolox_voc_tiny.py',
ckpt_path = '/workspace/tensorrt/YOLOX/best_ckpt.pth'
).cuda()
# 1. setup strategy (L1 Norm)
strategy = tp.strategy.L1Strategy() # or tp.strategy.RandomStrategy()

# %%
# 2. build dependency graph for resnet18
DG = tp.DependencyGraph()
DG.build_dependency(model, example_inputs=torch.randn(1,3,224,224).cuda())

# %%
temp = []
temp2 = list(model.state_dict().keys())
num_list = [0,1,2,3]
#print(temp2)
for i in range(len(temp2)):
        if 'bn' in temp2[i]:
            continue
        if 'weight' in temp2[i]:
            temp2[i] = temp2[i].replace('.weight','')
            temp2[i] = temp2[i].replace('2.0','2[0]')
            temp2[i] = temp2[i].replace('2.1','2[1]')
            temp2[i] = temp2[i].replace('3.0','3[0]')
            temp2[i] = temp2[i].replace('3.1','3[1]')
            temp2[i] = temp2[i].replace('4.0','4[0]')
            temp2[i] = temp2[i].replace('4.1','4[1]')
            temp2[i] = temp2[i].replace('5.0','5[0]')
            temp2[i] = temp2[i].replace('5.1','5[1]')
            temp2[i] = temp2[i].replace('5.2','5[2]')
            temp2[i] = temp2[i].replace('m.0','m[0]')
            temp2[i] = temp2[i].replace('m.1','m[1]')
            temp2[i] = temp2[i].replace('m.2','m[2]')
            temp.append(temp2[i])

print(temp)
# backbone 만 프루닝
# Out:
# ['backbone.backbone.stem.conv.conv', 'backbone.backbone.dark2[0].conv', 'backbone.backbone.dark2[1].conv1.conv', 'backbone.backbone.dark2[1].conv2.conv', 'backbone.backbone.dark2[1].conv3.conv', 'backbone.backbone.dark2[1].m[0].conv1.conv', 'backbone.backbone.dark2[1].m[0].conv2.conv', 'backbone.backbone.dark3[0].conv', 'backbone.backbone.dark3[1].conv1.conv', 'backbone.backbone.dark3[1].conv2.conv', 'backbone.backbone.dark3[1].conv3.conv', 'backbone.backbone.dark3[1].m[0].conv1.conv', 'backbone.backbone.dark3[1].m[0].conv2.conv', 'backbone.backbone.dark3[1].m[1].conv1.conv', 'backbone.backbone.dark3[1].m[1].conv2.conv', 'backbone.backbone.dark3[1].m[2].conv1.conv', 'backbone.backbone.dark3[1].m[2].conv2.conv', 'backbone.backbone.dark4[0].conv', 'backbone.backbone.dark4[1].conv1.conv', 'backbone.backbone.dark4[1].conv2.conv', 'backbone.backbone.dark4[1].conv3.conv', 'backbone.backbone.dark4[1].m[0].conv1.conv', 'backbone.backbone.dark4[1].m[0].conv2.conv', 'backbone.backbone.dark4[1].m[1].conv1.conv', 'backbone.backbone.dark4[1].m[1].conv2.conv', 'backbone.backbone.dark4[1].m[2].conv1.conv', 'backbone.backbone.dark4[1].m[2].conv2.conv', 'backbone.backbone.dark5[0].conv', 'backbone.backbone.dark5[1].conv1.conv', 'backbone.backbone.dark5[1].conv2.conv', 'backbone.backbone.dark5[2].conv1.conv', 'backbone.backbone.dark5[2].conv2.conv', 'backbone.backbone.dark5[2].conv3.conv', 'backbone.backbone.dark5[2].m[0].conv1.conv', 'backbone.backbone.dark5[2].m[0].conv2.conv', 'backbone.lateral_conv0.conv', 'backbone.C3_p4.conv1.conv', 'backbone.C3_p4.conv2.conv', 'backbone.C3_p4.conv3.conv', 'backbone.C3_p4.m[0].conv1.conv', 'backbone.C3_p4.m[0].conv2.conv', 'backbone.reduce_conv1.conv', 'backbone.C3_p3.conv1.conv', 'backbone.C3_p3.conv2.conv', 'backbone.C3_p3.conv3.conv', 'backbone.C3_p3.m[0].conv1.conv', 'backbone.C3_p3.m[0].conv2.conv', 'backbone.bu_conv2.conv', 'backbone.C3_n3.conv1.conv', 'backbone.C3_n3.conv2.conv', 'backbone.C3_n3.conv3.conv', 'backbone.C3_n3.m[0].conv1.conv', 'backbone.C3_n3.m[0].conv2.conv', 'backbone.bu_conv1.conv', 'backbone.C3_n4.conv1.conv', 'backbone.C3_n4.conv2.conv', 'backbone.C3_n4.conv3.conv', 'backbone.C3_n4.m[0].conv1.conv', 'backbone.C3_n4.m[0].conv2.conv', 'head.cls_convs.0.0.conv', 'head.cls_convs.0.1.conv', 'head.cls_convs.1.0.conv', 'head.cls_convs.1.1.conv', 'head.cls_convs.2[0].conv', 'head.cls_convs.2[1].conv', 'head.reg_convs.0.0.conv', 'head.reg_convs.0.1.conv', 'head.reg_convs.1.0.conv', 'head.reg_convs.1.1.conv', 'head.reg_convs.2[0].conv', 'head.reg_convs.2[1].conv', 'head.cls_preds.0', 'head.cls_preds.1', 'head.cls_preds.2', 'head.reg_preds.0', 'head.reg_preds.1', 'head.reg_preds.2', 'head.obj_preds.0', 'head.obj_preds.1', 'head.obj_preds.2', 'head.stems.0.conv', 'head.stems.1.conv', 'head.stems.2.conv']

# %%
print(model)
# Out:
# YOLOX(
#   (backbone): YOLOPAFPN(
#     (backbone): CSPDarknet(
#       (stem): Focus(
#         (conv): BaseConv(
#           (conv): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (dark2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(24, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark3): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(48, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark4): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark5): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): SPPBottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): ModuleList(
#             (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#             (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#             (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (upsample): Upsample(scale_factor=2.0, mode=nearest)
#     (lateral_conv0): BaseConv(
#       (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (reduce_conv1): BaseConv(
#       (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv2): BaseConv(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv1): BaseConv(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (head): YOLOXHead(
#     (cls_convs): ModuleList(
#       (0): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (reg_convs): ModuleList(
#       (0): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (cls_preds): ModuleList(
#       (0): Conv2d(96, 20, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 20, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 20, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (reg_preds): ModuleList(
#       (0): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (obj_preds): ModuleList(
#       (0): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stems): ModuleList(
#       (0): BaseConv(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): BaseConv(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): BaseConv(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (l1_loss): L1Loss()
#     (bcewithlog_loss): BCEWithLogitsLoss()
#     (iou_loss): IOUloss()
#   )
# )

# %%
from pruning_imagenet import Mask

# %%
m = Mask(model)

# %%
m.init_length()

# %%
m.init_mask(1, 0.21)
print(m.mask_index)
# Out:
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# mask Ready
# [24, 27, 30, 33, 39, 45, 54, 57, 60, 63, 69, 75, 90, 93, 99, 102, 96, 105, 108, 111, 114, 117, 120, 123, 141, 159]

# %%
m.do_mask()
m.do_similar_mask()
# Out:
# mask Done
# mask similar Done

# %%
m.if_zero()
print(m.mask_index)
print(m.similar_matrix)
# Out:
# layer: 24, number of nonzero weight is 3648, zero is 960
# layer: 27, number of nonzero weight is 3648, zero is 960
# layer: 30, number of nonzero weight is 7296, zero is 1920
# layer: 33, number of nonzero weight is 1824, zero is 480
# layer: 39, number of nonzero weight is 1824, zero is 480
# layer: 45, number of nonzero weight is 1824, zero is 480
# layer: 54, number of nonzero weight is 14592, zero is 3840
# layer: 57, number of nonzero weight is 14592, zero is 3840
# layer: 60, number of nonzero weight is 29184, zero is 7680
# layer: 63, number of nonzero weight is 7296, zero is 1920
# layer: 69, number of nonzero weight is 7296, zero is 1920
# layer: 75, number of nonzero weight is 7296, zero is 1920
# layer: 90, number of nonzero weight is 58368, zero is 15360
# layer: 93, number of nonzero weight is 58368, zero is 15360
# layer: 96, number of nonzero weight is 116736, zero is 30720
# layer: 99, number of nonzero weight is 29184, zero is 7680
# layer: 102, number of nonzero weight is 262656, zero is 69120
# layer: 105, number of nonzero weight is 58368, zero is 15360
# layer: 108, number of nonzero weight is 29184, zero is 7680
# layer: 111, number of nonzero weight is 29184, zero is 7680
# layer: 114, number of nonzero weight is 29184, zero is 7680
# layer: 117, number of nonzero weight is 7296, zero is 1920
# layer: 120, number of nonzero weight is 65664, zero is 17280
# layer: 123, number of nonzero weight is 14592, zero is 3840
# layer: 141, number of nonzero weight is 65664, zero is 17280
# layer: 159, number of nonzero weight is 262656, zero is 69120
# [24, 27, 30, 33, 39, 45, 54, 57, 60, 63, 69, 75, 90, 93, 99, 102, 96, 105, 108, 111, 114, 117, 120, 123, 141, 159]
# {24: tensor([0., 0., 0.,  ..., 1., 1., 1.], device='cuda:0'), 27: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 30: tensor([1., 1., 1.,  ..., 0., 0., 0.], device='cuda:0'), 33: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 39: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 45: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 54: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 57: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 60: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 63: tensor([0., 0., 0.,  ..., 1., 1., 1.], device='cuda:0'), 69: tensor([1., 1., 1.,  ..., 0., 0., 0.], device='cuda:0'), 75: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 90: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 93: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 96: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 99: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 102: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 105: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 108: tensor([1., 1., 1.,  ..., 0., 0., 0.], device='cuda:0'), 111: tensor([1., 1., 1.,  ..., 0., 0., 0.], device='cuda:0'), 114: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 117: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 120: tensor([1., 1., 1.,  ..., 0., 0., 0.], device='cuda:0'), 123: tensor([0., 0., 0.,  ..., 1., 1., 1.], device='cuda:0'), 141: tensor([0., 0., 0.,  ..., 1., 1., 1.], device='cuda:0'), 159: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0')}

# %%
model = m.model

# %%
dict ={}


for key, value in model.state_dict().items():
    temp = []
    if len(value.shape) ==4:
        print('pruning channel and layer name : ',len(value),',', key)
        for i in range(len(value)):
            temp
            if value[i].sum() == 0: 
                print('pruning channex index : ', i)
                #temp = torch.norm(value.view(len(value), -1) , p= 1, dim=1)
                #print(temp)
                #dict[key].append(i)
                temp.append(i)
    if temp:   
        dict[key]  = temp
# Out:
# pruning channel and layer name :  24 , backbone.backbone.stem.conv.conv.weight
# pruning channel and layer name :  48 , backbone.backbone.dark2.0.conv.weight
# pruning channel and layer name :  24 , backbone.backbone.dark2.1.conv1.conv.weight
# pruning channel and layer name :  24 , backbone.backbone.dark2.1.conv2.conv.weight
# pruning channel and layer name :  48 , backbone.backbone.dark2.1.conv3.conv.weight
# pruning channel and layer name :  24 , backbone.backbone.dark2.1.m.0.conv1.conv.weight
# pruning channel and layer name :  24 , backbone.backbone.dark2.1.m.0.conv2.conv.weight
# pruning channel and layer name :  96 , backbone.backbone.dark3.0.conv.weight
# pruning channel and layer name :  48 , backbone.backbone.dark3.1.conv1.conv.weight
# pruning channex index :  0
# pruning channex index :  22
# pruning channex index :  23
# pruning channex index :  24
# pruning channex index :  25
# pruning channex index :  26
# pruning channex index :  30
# pruning channex index :  31
# pruning channex index :  37
# pruning channex index :  42
# pruning channel and layer name :  48 , backbone.backbone.dark3.1.conv2.conv.weight
# pruning channex index :  6
# pruning channex index :  20
# pruning channex index :  26
# pruning channex index :  29
# pruning channex index :  30
# pruning channex index :  31
# pruning channex index :  34
# pruning channex index :  37
# pruning channex index :  38
# pruning channex index :  41
# pruning channel and layer name :  96 , backbone.backbone.dark3.1.conv3.conv.weight
# pruning channex index :  1
# pruning channex index :  8
# pruning channex index :  12
# pruning channex index :  15
# pruning channex index :  17
# pruning channex index :  18
# pruning channex index :  21
# pruning channex index :  29
# pruning channex index :  34
# pruning channex index :  37
# pruning channex index :  51
# pruning channex index :  55
# pruning channex index :  65
# pruning channex index :  66
# pruning channex index :  67
# pruning channex index :  70
# pruning channex index :  79
# pruning channex index :  81
# pruning channex index :  90
# pruning channex index :  95
# pruning channel and layer name :  48 , backbone.backbone.dark3.1.m.0.conv1.conv.weight
# pruning channex index :  4
# pruning channex index :  14
# pruning channex index :  18
# pruning channex index :  21
# pruning channex index :  27
# pruning channex index :  36
# pruning channex index :  37
# pruning channex index :  38
# pruning channex index :  41
# pruning channex index :  43
# pruning channel and layer name :  48 , backbone.backbone.dark3.1.m.0.conv2.conv.weight
# pruning channel and layer name :  48 , backbone.backbone.dark3.1.m.1.conv1.conv.weight
# pruning channex index :  1
# pruning channex index :  11
# pruning channex index :  12
# pruning channex index :  16
# pruning channex index :  18
# pruning channex index :  23
# pruning channex index :  26
# pruning channex index :  33
# pruning channex index :  38
# pruning channex index :  42
# pruning channel and layer name :  48 , backbone.backbone.dark3.1.m.1.conv2.conv.weight
# pruning channel and layer name :  48 , backbone.backbone.dark3.1.m.2.conv1.conv.weight
# pruning channex index :  2
# pruning channex index :  12
# pruning channex index :  15
# pruning channex index :  27
# pruning channex index :  29
# pruning channex index :  30
# pruning channex index :  33
# pruning channex index :  34
# pruning channex index :  36
# pruning channex index :  40
# pruning channel and layer name :  48 , backbone.backbone.dark3.1.m.2.conv2.conv.weight
# pruning channel and layer name :  192 , backbone.backbone.dark4.0.conv.weight
# pruning channel and layer name :  96 , backbone.backbone.dark4.1.conv1.conv.weight
# pruning channex index :  4
# pruning channex index :  9
# pruning channex index :  17
# pruning channex index :  19
# pruning channex index :  23
# pruning channex index :  24
# pruning channex index :  25
# pruning channex index :  26
# pruning channex index :  31
# pruning channex index :  46
# pruning channex index :  59
# pruning channex index :  63
# pruning channex index :  64
# pruning channex index :  66
# pruning channex index :  72
# pruning channex index :  75
# pruning channex index :  80
# pruning channex index :  84
# pruning channex index :  85
# pruning channex index :  89
# pruning channel and layer name :  96 , backbone.backbone.dark4.1.conv2.conv.weight
# pruning channex index :  1
# pruning channex index :  2
# pruning channex index :  9
# pruning channex index :  14
# pruning channex index :  19
# pruning channex index :  26
# pruning channex index :  35
# pruning channex index :  39
# pruning channex index :  42
# pruning channex index :  43
# pruning channex index :  48
# pruning channex index :  56
# pruning channex index :  72
# pruning channex index :  74
# pruning channex index :  75
# pruning channex index :  84
# pruning channex index :  85
# pruning channex index :  86
# pruning channex index :  92
# pruning channex index :  94
# pruning channel and layer name :  192 , backbone.backbone.dark4.1.conv3.conv.weight
# pruning channex index :  4
# pruning channex index :  5
# pruning channex index :  10
# pruning channex index :  19
# pruning channex index :  20
# pruning channex index :  21
# pruning channex index :  34
# pruning channex index :  39
# pruning channex index :  41
# pruning channex index :  45
# pruning channex index :  63
# pruning channex index :  64
# pruning channex index :  72
# pruning channex index :  83
# pruning channex index :  84
# pruning channex index :  89
# pruning channex index :  95
# pruning channex index :  99
# pruning channex index :  101
# pruning channex index :  102
# pruning channex index :  103
# pruning channex index :  106
# pruning channex index :  113
# pruning channex index :  118
# pruning channex index :  120
# pruning channex index :  122
# pruning channex index :  132
# pruning channex index :  148
# pruning channex index :  149
# pruning channex index :  151
# pruning channex index :  152
# pruning channex index :  162
# pruning channex index :  168
# pruning channex index :  170
# pruning channex index :  172
# pruning channex index :  177
# pruning channex index :  181
# pruning channex index :  183
# pruning channex index :  186
# pruning channex index :  188
# pruning channel and layer name :  96 , backbone.backbone.dark4.1.m.0.conv1.conv.weight
# pruning channex index :  0
# pruning channex index :  20
# pruning channex index :  22
# pruning channex index :  37
# pruning channex index :  39
# pruning channex index :  40
# pruning channex index :  41
# pruning channex index :  47
# pruning channex index :  49
# pruning channex index :  53
# pruning channex index :  54
# pruning channex index :  60
# pruning channex index :  62
# pruning channex index :  63
# pruning channex index :  71
# pruning channex index :  72
# pruning channex index :  73
# pruning channex index :  75
# pruning channex index :  91
# pruning channex index :  93
# pruning channel and layer name :  96 , backbone.backbone.dark4.1.m.0.conv2.conv.weight
# pruning channel and layer name :  96 , backbone.backbone.dark4.1.m.1.conv1.conv.weight
# pruning channex index :  18
# pruning channex index :  27
# pruning channex index :  29
# pruning channex index :  33
# pruning channex index :  40
# pruning channex index :  41
# pruning channex index :  43
# pruning channex index :  44
# pruning channex index :  47
# pruning channex index :  48
# pruning channex index :  50
# pruning channex index :  54
# pruning channex index :  56
# pruning channex index :  58
# pruning channex index :  60
# pruning channex index :  68
# pruning channex index :  84
# pruning channex index :  93
# pruning channex index :  94
# pruning channex index :  95
# pruning channel and layer name :  96 , backbone.backbone.dark4.1.m.1.conv2.conv.weight
# pruning channel and layer name :  96 , backbone.backbone.dark4.1.m.2.conv1.conv.weight
# pruning channex index :  6
# pruning channex index :  11
# pruning channex index :  16
# pruning channex index :  17
# pruning channex index :  20
# pruning channex index :  23
# pruning channex index :  28
# pruning channex index :  33
# pruning channex index :  35
# pruning channex index :  38
# pruning channex index :  40
# pruning channex index :  47
# pruning channex index :  50
# pruning channex index :  55
# pruning channex index :  71
# pruning channex index :  78
# pruning channex index :  88
# pruning channex index :  89
# pruning channex index :  90
# pruning channex index :  92
# pruning channel and layer name :  96 , backbone.backbone.dark4.1.m.2.conv2.conv.weight
# pruning channel and layer name :  384 , backbone.backbone.dark5.0.conv.weight
# pruning channel and layer name :  192 , backbone.backbone.dark5.1.conv1.conv.weight
# pruning channel and layer name :  384 , backbone.backbone.dark5.1.conv2.conv.weight
# pruning channel and layer name :  192 , backbone.backbone.dark5.2.conv1.conv.weight
# pruning channex index :  1
# pruning channex index :  6
# pruning channex index :  10
# pruning channex index :  11
# pruning channex index :  16
# pruning channex index :  19
# pruning channex index :  21
# pruning channex index :  28
# pruning channex index :  29
# pruning channex index :  30
# pruning channex index :  32
# pruning channex index :  33
# pruning channex index :  41
# pruning channex index :  45
# pruning channex index :  50
# pruning channex index :  52
# pruning channex index :  63
# pruning channex index :  74
# pruning channex index :  81
# pruning channex index :  83
# pruning channex index :  87
# pruning channex index :  90
# pruning channex index :  91
# pruning channex index :  93
# pruning channex index :  103
# pruning channex index :  104
# pruning channex index :  111
# pruning channex index :  113
# pruning channex index :  117
# pruning channex index :  131
# pruning channex index :  132
# pruning channex index :  140
# pruning channex index :  141
# pruning channex index :  154
# pruning channex index :  158
# pruning channex index :  165
# pruning channex index :  169
# pruning channex index :  176
# pruning channex index :  179
# pruning channex index :  187
# pruning channel and layer name :  192 , backbone.backbone.dark5.2.conv2.conv.weight
# pruning channex index :  2
# pruning channex index :  12
# pruning channex index :  13
# pruning channex index :  16
# pruning channex index :  25
# pruning channex index :  29
# pruning channex index :  30
# pruning channex index :  33
# pruning channex index :  34
# pruning channex index :  45
# pruning channex index :  46
# pruning channex index :  49
# pruning channex index :  51
# pruning channex index :  55
# pruning channex index :  61
# pruning channex index :  65
# pruning channex index :  67
# pruning channex index :  74
# pruning channex index :  77
# pruning channex index :  78
# pruning channex index :  106
# pruning channex index :  109
# pruning channex index :  126
# pruning channex index :  127
# pruning channex index :  136
# pruning channex index :  138
# pruning channex index :  139
# pruning channex index :  152
# pruning channex index :  158
# pruning channex index :  160
# pruning channex index :  161
# pruning channex index :  164
# pruning channex index :  166
# pruning channex index :  168
# pruning channex index :  170
# pruning channex index :  171
# pruning channex index :  173
# pruning channex index :  174
# pruning channex index :  186
# pruning channex index :  188
# pruning channel and layer name :  384 , backbone.backbone.dark5.2.conv3.conv.weight
# pruning channex index :  3
# pruning channex index :  5
# pruning channex index :  18
# pruning channex index :  19
# pruning channex index :  21
# pruning channex index :  30
# pruning channex index :  42
# pruning channex index :  44
# pruning channex index :  45
# pruning channex index :  56
# pruning channex index :  60
# pruning channex index :  73
# pruning channex index :  74
# pruning channex index :  78
# pruning channex index :  79
# pruning channex index :  80
# pruning channex index :  82
# pruning channex index :  85
# pruning channex index :  86
# pruning channex index :  96
# pruning channex index :  97
# pruning channex index :  101
# pruning channex index :  102
# pruning channex index :  114
# pruning channex index :  117
# pruning channex index :  126
# pruning channex index :  129
# pruning channex index :  132
# pruning channex index :  143
# pruning channex index :  151
# pruning channex index :  159
# pruning channex index :  161
# pruning channex index :  165
# pruning channex index :  170
# pruning channex index :  175
# pruning channex index :  181
# pruning channex index :  183
# pruning channex index :  186
# pruning channex index :  193
# pruning channex index :  195
# pruning channex index :  196
# pruning channex index :  201
# pruning channex index :  202
# pruning channex index :  218
# pruning channex index :  222
# pruning channex index :  240
# pruning channex index :  242
# pruning channex index :  245
# pruning channex index :  248
# pruning channex index :  252
# pruning channex index :  253
# pruning channex index :  257
# pruning channex index :  258
# pruning channex index :  259
# pruning channex index :  264
# pruning channex index :  269
# pruning channex index :  273
# pruning channex index :  278
# pruning channex index :  283
# pruning channex index :  285
# pruning channex index :  297
# pruning channex index :  301
# pruning channex index :  310
# pruning channex index :  317
# pruning channex index :  328
# pruning channex index :  333
# pruning channex index :  335
# pruning channex index :  338
# pruning channex index :  339
# pruning channex index :  344
# pruning channex index :  345
# pruning channex index :  347
# pruning channex index :  350
# pruning channex index :  355
# pruning channex index :  357
# pruning channex index :  362
# pruning channex index :  371
# pruning channex index :  375
# pruning channex index :  378
# pruning channex index :  382
# pruning channel and layer name :  192 , backbone.backbone.dark5.2.m.0.conv1.conv.weight
# pruning channex index :  1
# pruning channex index :  4
# pruning channex index :  7
# pruning channex index :  10
# pruning channex index :  11
# pruning channex index :  15
# pruning channex index :  25
# pruning channex index :  36
# pruning channex index :  37
# pruning channex index :  47
# pruning channex index :  51
# pruning channex index :  58
# pruning channex index :  61
# pruning channex index :  70
# pruning channex index :  75
# pruning channex index :  82
# pruning channex index :  83
# pruning channex index :  85
# pruning channex index :  88
# pruning channex index :  97
# pruning channex index :  100
# pruning channex index :  103
# pruning channex index :  105
# pruning channex index :  107
# pruning channex index :  115
# pruning channex index :  125
# pruning channex index :  127
# pruning channex index :  129
# pruning channex index :  132
# pruning channex index :  136
# pruning channex index :  145
# pruning channex index :  150
# pruning channex index :  156
# pruning channex index :  158
# pruning channex index :  164
# pruning channex index :  168
# pruning channex index :  169
# pruning channex index :  178
# pruning channex index :  180
# pruning channex index :  184
# pruning channel and layer name :  192 , backbone.backbone.dark5.2.m.0.conv2.conv.weight
# pruning channex index :  4
# pruning channex index :  9
# pruning channex index :  10
# pruning channex index :  18
# pruning channex index :  19
# pruning channex index :  23
# pruning channex index :  27
# pruning channex index :  31
# pruning channex index :  38
# pruning channex index :  39
# pruning channex index :  55
# pruning channex index :  63
# pruning channex index :  71
# pruning channex index :  77
# pruning channex index :  88
# pruning channex index :  90
# pruning channex index :  92
# pruning channex index :  99
# pruning channex index :  103
# pruning channex index :  109
# pruning channex index :  113
# pruning channex index :  115
# pruning channex index :  119
# pruning channex index :  126
# pruning channex index :  127
# pruning channex index :  130
# pruning channex index :  132
# pruning channex index :  138
# pruning channex index :  139
# pruning channex index :  148
# pruning channex index :  155
# pruning channex index :  158
# pruning channex index :  165
# pruning channex index :  175
# pruning channex index :  179
# pruning channex index :  180
# pruning channex index :  182
# pruning channex index :  183
# pruning channex index :  184
# pruning channex index :  190
# pruning channel and layer name :  192 , backbone.lateral_conv0.conv.weight
# pruning channex index :  10
# pruning channex index :  16
# pruning channex index :  17
# pruning channex index :  18
# pruning channex index :  32
# pruning channex index :  35
# pruning channex index :  51
# pruning channex index :  53
# pruning channex index :  54
# pruning channex index :  63
# pruning channex index :  69
# pruning channex index :  73
# pruning channex index :  74
# pruning channex index :  81
# pruning channex index :  84
# pruning channex index :  102
# pruning channex index :  104
# pruning channex index :  107
# pruning channex index :  111
# pruning channex index :  120
# pruning channex index :  121
# pruning channex index :  133
# pruning channex index :  137
# pruning channex index :  139
# pruning channex index :  140
# pruning channex index :  142
# pruning channex index :  144
# pruning channex index :  146
# pruning channex index :  155
# pruning channex index :  162
# pruning channex index :  164
# pruning channex index :  172
# pruning channex index :  175
# pruning channex index :  176
# pruning channex index :  178
# pruning channex index :  181
# pruning channex index :  182
# pruning channex index :  184
# pruning channex index :  185
# pruning channex index :  186
# pruning channel and layer name :  96 , backbone.C3_p4.conv1.conv.weight
# pruning channex index :  12
# pruning channex index :  15
# pruning channex index :  17
# pruning channex index :  35
# pruning channex index :  36
# pruning channex index :  37
# pruning channex index :  38
# pruning channex index :  42
# pruning channex index :  46
# pruning channex index :  56
# pruning channex index :  58
# pruning channex index :  66
# pruning channex index :  70
# pruning channex index :  73
# pruning channex index :  82
# pruning channex index :  84
# pruning channex index :  85
# pruning channex index :  86
# pruning channex index :  88
# pruning channex index :  95
# pruning channel and layer name :  96 , backbone.C3_p4.conv2.conv.weight
# pruning channex index :  10
# pruning channex index :  13
# pruning channex index :  15
# pruning channex index :  16
# pruning channex index :  26
# pruning channex index :  28
# pruning channex index :  41
# pruning channex index :  44
# pruning channex index :  45
# pruning channex index :  47
# pruning channex index :  48
# pruning channex index :  57
# pruning channex index :  59
# pruning channex index :  65
# pruning channex index :  66
# pruning channex index :  70
# pruning channex index :  76
# pruning channex index :  81
# pruning channex index :  87
# pruning channex index :  95
# pruning channel and layer name :  192 , backbone.C3_p4.conv3.conv.weight
# pruning channex index :  1
# pruning channex index :  3
# pruning channex index :  16
# pruning channex index :  21
# pruning channex index :  29
# pruning channex index :  37
# pruning channex index :  44
# pruning channex index :  47
# pruning channex index :  58
# pruning channex index :  59
# pruning channex index :  62
# pruning channex index :  67
# pruning channex index :  68
# pruning channex index :  71
# pruning channex index :  77
# pruning channex index :  78
# pruning channex index :  80
# pruning channex index :  85
# pruning channex index :  86
# pruning channex index :  90
# pruning channex index :  91
# pruning channex index :  93
# pruning channex index :  103
# pruning channex index :  107
# pruning channex index :  113
# pruning channex index :  124
# pruning channex index :  133
# pruning channex index :  139
# pruning channex index :  140
# pruning channex index :  147
# pruning channex index :  158
# pruning channex index :  160
# pruning channex index :  163
# pruning channex index :  167
# pruning channex index :  176
# pruning channex index :  180
# pruning channex index :  182
# pruning channex index :  184
# pruning channex index :  186
# pruning channex index :  188
# pruning channel and layer name :  96 , backbone.C3_p4.m.0.conv1.conv.weight
# pruning channex index :  3
# pruning channex index :  6
# pruning channex index :  9
# pruning channex index :  13
# pruning channex index :  17
# pruning channex index :  23
# pruning channex index :  47
# pruning channex index :  52
# pruning channex index :  53
# pruning channex index :  57
# pruning channex index :  61
# pruning channex index :  66
# pruning channex index :  67
# pruning channex index :  77
# pruning channex index :  81
# pruning channex index :  82
# pruning channex index :  89
# pruning channex index :  90
# pruning channex index :  92
# pruning channex index :  94
# pruning channel and layer name :  96 , backbone.C3_p4.m.0.conv2.conv.weight
# pruning channex index :  6
# pruning channex index :  11
# pruning channex index :  19
# pruning channex index :  22
# pruning channex index :  24
# pruning channex index :  27
# pruning channex index :  28
# pruning channex index :  44
# pruning channex index :  57
# pruning channex index :  60
# pruning channex index :  63
# pruning channex index :  66
# pruning channex index :  67
# pruning channex index :  74
# pruning channex index :  76
# pruning channex index :  79
# pruning channex index :  80
# pruning channex index :  81
# pruning channex index :  88
# pruning channex index :  95
# pruning channel and layer name :  96 , backbone.reduce_conv1.conv.weight
# pruning channex index :  0
# pruning channex index :  5
# pruning channex index :  16
# pruning channex index :  20
# pruning channex index :  22
# pruning channex index :  31
# pruning channex index :  34
# pruning channex index :  40
# pruning channex index :  46
# pruning channex index :  51
# pruning channex index :  54
# pruning channex index :  61
# pruning channex index :  68
# pruning channex index :  73
# pruning channex index :  76
# pruning channex index :  77
# pruning channex index :  78
# pruning channex index :  79
# pruning channex index :  89
# pruning channex index :  92
# pruning channel and layer name :  48 , backbone.C3_p3.conv1.conv.weight
# pruning channel and layer name :  48 , backbone.C3_p3.conv2.conv.weight
# pruning channel and layer name :  96 , backbone.C3_p3.conv3.conv.weight
# pruning channel and layer name :  48 , backbone.C3_p3.m.0.conv1.conv.weight
# pruning channel and layer name :  48 , backbone.C3_p3.m.0.conv2.conv.weight
# pruning channel and layer name :  96 , backbone.bu_conv2.conv.weight
# pruning channex index :  0
# pruning channex index :  2
# pruning channex index :  5
# pruning channex index :  12
# pruning channex index :  13
# pruning channex index :  14
# pruning channex index :  19
# pruning channex index :  22
# pruning channex index :  26
# pruning channex index :  33
# pruning channex index :  41
# pruning channex index :  43
# pruning channex index :  52
# pruning channex index :  54
# pruning channex index :  56
# pruning channex index :  63
# pruning channex index :  66
# pruning channex index :  82
# pruning channex index :  85
# pruning channex index :  87
# pruning channel and layer name :  96 , backbone.C3_n3.conv1.conv.weight
# pruning channel and layer name :  96 , backbone.C3_n3.conv2.conv.weight
# pruning channel and layer name :  192 , backbone.C3_n3.conv3.conv.weight
# pruning channel and layer name :  96 , backbone.C3_n3.m.0.conv1.conv.weight
# pruning channel and layer name :  96 , backbone.C3_n3.m.0.conv2.conv.weight
# pruning channel and layer name :  192 , backbone.bu_conv1.conv.weight
# pruning channex index :  11
# pruning channex index :  14
# pruning channex index :  16
# pruning channex index :  18
# pruning channex index :  26
# pruning channex index :  28
# pruning channex index :  29
# pruning channex index :  30
# pruning channex index :  40
# pruning channex index :  42
# pruning channex index :  43
# pruning channex index :  48
# pruning channex index :  49
# pruning channex index :  54
# pruning channex index :  60
# pruning channex index :  64
# pruning channex index :  73
# pruning channex index :  76
# pruning channex index :  83
# pruning channex index :  94
# pruning channex index :  96
# pruning channex index :  100
# pruning channex index :  105
# pruning channex index :  106
# pruning channex index :  117
# pruning channex index :  122
# pruning channex index :  123
# pruning channex index :  138
# pruning channex index :  145
# pruning channex index :  149
# pruning channex index :  164
# pruning channex index :  166
# pruning channex index :  172
# pruning channex index :  175
# pruning channex index :  176
# pruning channex index :  179
# pruning channex index :  180
# pruning channex index :  182
# pruning channex index :  184
# pruning channex index :  189
# pruning channel and layer name :  192 , backbone.C3_n4.conv1.conv.weight
# pruning channel and layer name :  192 , backbone.C3_n4.conv2.conv.weight
# pruning channel and layer name :  384 , backbone.C3_n4.conv3.conv.weight
# pruning channel and layer name :  192 , backbone.C3_n4.m.0.conv1.conv.weight
# pruning channel and layer name :  192 , backbone.C3_n4.m.0.conv2.conv.weight
# pruning channel and layer name :  96 , head.cls_convs.0.0.conv.weight
# pruning channel and layer name :  96 , head.cls_convs.0.1.conv.weight
# pruning channel and layer name :  96 , head.cls_convs.1.0.conv.weight
# pruning channel and layer name :  96 , head.cls_convs.1.1.conv.weight
# pruning channel and layer name :  96 , head.cls_convs.2.0.conv.weight
# pruning channel and layer name :  96 , head.cls_convs.2.1.conv.weight
# pruning channel and layer name :  96 , head.reg_convs.0.0.conv.weight
# pruning channel and layer name :  96 , head.reg_convs.0.1.conv.weight
# pruning channel and layer name :  96 , head.reg_convs.1.0.conv.weight
# pruning channel and layer name :  96 , head.reg_convs.1.1.conv.weight
# pruning channel and layer name :  96 , head.reg_convs.2.0.conv.weight
# pruning channel and layer name :  96 , head.reg_convs.2.1.conv.weight
# pruning channel and layer name :  20 , head.cls_preds.0.weight
# pruning channel and layer name :  20 , head.cls_preds.1.weight
# pruning channel and layer name :  20 , head.cls_preds.2.weight
# pruning channel and layer name :  4 , head.reg_preds.0.weight
# pruning channel and layer name :  4 , head.reg_preds.1.weight
# pruning channel and layer name :  4 , head.reg_preds.2.weight
# pruning channel and layer name :  1 , head.obj_preds.0.weight
# pruning channel and layer name :  1 , head.obj_preds.1.weight
# pruning channel and layer name :  1 , head.obj_preds.2.weight
# pruning channel and layer name :  96 , head.stems.0.conv.weight
# pruning channel and layer name :  96 , head.stems.1.conv.weight
# pruning channel and layer name :  96 , head.stems.2.conv.weight

# %%
print(dict)
#del dict['backbone.backbone.dark3.1.conv3.conv.weight'][0]
# Out:
# {'backbone.backbone.dark3.1.conv1.conv.weight': [0, 22, 23, 24, 25, 26, 30, 31, 37, 42], 'backbone.backbone.dark3.1.conv2.conv.weight': [6, 20, 26, 29, 30, 31, 34, 37, 38, 41], 'backbone.backbone.dark3.1.conv3.conv.weight': [1, 8, 12, 15, 17, 18, 21, 29, 34, 37, 51, 55, 65, 66, 67, 70, 79, 81, 90, 95], 'backbone.backbone.dark3.1.m.0.conv1.conv.weight': [4, 14, 18, 21, 27, 36, 37, 38, 41, 43], 'backbone.backbone.dark3.1.m.1.conv1.conv.weight': [1, 11, 12, 16, 18, 23, 26, 33, 38, 42], 'backbone.backbone.dark3.1.m.2.conv1.conv.weight': [2, 12, 15, 27, 29, 30, 33, 34, 36, 40], 'backbone.backbone.dark4.1.conv1.conv.weight': [4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], 'backbone.backbone.dark4.1.conv2.conv.weight': [1, 2, 9, 14, 19, 26, 35, 39, 42, 43, 48, 56, 72, 74, 75, 84, 85, 86, 92, 94], 'backbone.backbone.dark4.1.conv3.conv.weight': [4, 5, 10, 19, 20, 21, 34, 39, 41, 45, 63, 64, 72, 83, 84, 89, 95, 99, 101, 102, 103, 106, 113, 118, 120, 122, 132, 148, 149, 151, 152, 162, 168, 170, 172, 177, 181, 183, 186, 188], 'backbone.backbone.dark4.1.m.0.conv1.conv.weight': [0, 20, 22, 37, 39, 40, 41, 47, 49, 53, 54, 60, 62, 63, 71, 72, 73, 75, 91, 93], 'backbone.backbone.dark4.1.m.1.conv1.conv.weight': [18, 27, 29, 33, 40, 41, 43, 44, 47, 48, 50, 54, 56, 58, 60, 68, 84, 93, 94, 95], 'backbone.backbone.dark4.1.m.2.conv1.conv.weight': [6, 11, 16, 17, 20, 23, 28, 33, 35, 38, 40, 47, 50, 55, 71, 78, 88, 89, 90, 92], 'backbone.backbone.dark5.2.conv1.conv.weight': [1, 6, 10, 11, 16, 19, 21, 28, 29, 30, 32, 33, 41, 45, 50, 52, 63, 74, 81, 83, 87, 90, 91, 93, 103, 104, 111, 113, 117, 131, 132, 140, 141, 154, 158, 165, 169, 176, 179, 187], 'backbone.backbone.dark5.2.conv2.conv.weight': [2, 12, 13, 16, 25, 29, 30, 33, 34, 45, 46, 49, 51, 55, 61, 65, 67, 74, 77, 78, 106, 109, 126, 127, 136, 138, 139, 152, 158, 160, 161, 164, 166, 168, 170, 171, 173, 174, 186, 188], 'backbone.backbone.dark5.2.conv3.conv.weight': [3, 5, 18, 19, 21, 30, 42, 44, 45, 56, 60, 73, 74, 78, 79, 80, 82, 85, 86, 96, 97, 101, 102, 114, 117, 126, 129, 132, 143, 151, 159, 161, 165, 170, 175, 181, 183, 186, 193, 195, 196, 201, 202, 218, 222, 240, 242, 245, 248, 252, 253, 257, 258, 259, 264, 269, 273, 278, 283, 285, 297, 301, 310, 317, 328, 333, 335, 338, 339, 344, 345, 347, 350, 355, 357, 362, 371, 375, 378, 382], 'backbone.backbone.dark5.2.m.0.conv1.conv.weight': [1, 4, 7, 10, 11, 15, 25, 36, 37, 47, 51, 58, 61, 70, 75, 82, 83, 85, 88, 97, 100, 103, 105, 107, 115, 125, 127, 129, 132, 136, 145, 150, 156, 158, 164, 168, 169, 178, 180, 184], 'backbone.backbone.dark5.2.m.0.conv2.conv.weight': [4, 9, 10, 18, 19, 23, 27, 31, 38, 39, 55, 63, 71, 77, 88, 90, 92, 99, 103, 109, 113, 115, 119, 126, 127, 130, 132, 138, 139, 148, 155, 158, 165, 175, 179, 180, 182, 183, 184, 190], 'backbone.lateral_conv0.conv.weight': [10, 16, 17, 18, 32, 35, 51, 53, 54, 63, 69, 73, 74, 81, 84, 102, 104, 107, 111, 120, 121, 133, 137, 139, 140, 142, 144, 146, 155, 162, 164, 172, 175, 176, 178, 181, 182, 184, 185, 186], 'backbone.C3_p4.conv1.conv.weight': [12, 15, 17, 35, 36, 37, 38, 42, 46, 56, 58, 66, 70, 73, 82, 84, 85, 86, 88, 95], 'backbone.C3_p4.conv2.conv.weight': [10, 13, 15, 16, 26, 28, 41, 44, 45, 47, 48, 57, 59, 65, 66, 70, 76, 81, 87, 95], 'backbone.C3_p4.conv3.conv.weight': [1, 3, 16, 21, 29, 37, 44, 47, 58, 59, 62, 67, 68, 71, 77, 78, 80, 85, 86, 90, 91, 93, 103, 107, 113, 124, 133, 139, 140, 147, 158, 160, 163, 167, 176, 180, 182, 184, 186, 188], 'backbone.C3_p4.m.0.conv1.conv.weight': [3, 6, 9, 13, 17, 23, 47, 52, 53, 57, 61, 66, 67, 77, 81, 82, 89, 90, 92, 94], 'backbone.C3_p4.m.0.conv2.conv.weight': [6, 11, 19, 22, 24, 27, 28, 44, 57, 60, 63, 66, 67, 74, 76, 79, 80, 81, 88, 95], 'backbone.reduce_conv1.conv.weight': [0, 5, 16, 20, 22, 31, 34, 40, 46, 51, 54, 61, 68, 73, 76, 77, 78, 79, 89, 92], 'backbone.bu_conv2.conv.weight': [0, 2, 5, 12, 13, 14, 19, 22, 26, 33, 41, 43, 52, 54, 56, 63, 66, 82, 85, 87], 'backbone.bu_conv1.conv.weight': [11, 14, 16, 18, 26, 28, ...

# %%
temp = []
temp2 = list(dict.keys())
for i in range(len(temp2)):
        if 'bn' in temp2[i]:
            continue
        if 'weight' in temp2[i]:
            temp2[i] = temp2[i].replace('.weight','')
            temp2[i] = temp2[i].replace('2.0','2[0]')
            temp2[i] = temp2[i].replace('2.1','2[1]')
            temp2[i] = temp2[i].replace('3.0','3[0]')
            temp2[i] = temp2[i].replace('3.1','3[1]')
            temp2[i] = temp2[i].replace('4.0','4[0]')
            temp2[i] = temp2[i].replace('4.1','4[1]')
            temp2[i] = temp2[i].replace('5.0','5[0]')
            temp2[i] = temp2[i].replace('5.1','5[1]')
            temp2[i] = temp2[i].replace('5.2','5[2]')
            temp2[i] = temp2[i].replace('m.0','m[0]')
            temp2[i] = temp2[i].replace('m.1','m[1]')
            temp2[i] = temp2[i].replace('m.2','m[2]')
            temp.append(temp2[i])

print(temp)
# Out:
# ['backbone.backbone.dark3[1].conv1.conv', 'backbone.backbone.dark3[1].conv2.conv', 'backbone.backbone.dark3[1].conv3.conv', 'backbone.backbone.dark3[1].m[0].conv1.conv', 'backbone.backbone.dark3[1].m[1].conv1.conv', 'backbone.backbone.dark3[1].m[2].conv1.conv', 'backbone.backbone.dark4[1].conv1.conv', 'backbone.backbone.dark4[1].conv2.conv', 'backbone.backbone.dark4[1].conv3.conv', 'backbone.backbone.dark4[1].m[0].conv1.conv', 'backbone.backbone.dark4[1].m[1].conv1.conv', 'backbone.backbone.dark4[1].m[2].conv1.conv', 'backbone.backbone.dark5[2].conv1.conv', 'backbone.backbone.dark5[2].conv2.conv', 'backbone.backbone.dark5[2].conv3.conv', 'backbone.backbone.dark5[2].m[0].conv1.conv', 'backbone.backbone.dark5[2].m[0].conv2.conv', 'backbone.lateral_conv0.conv', 'backbone.C3_p4.conv1.conv', 'backbone.C3_p4.conv2.conv', 'backbone.C3_p4.conv3.conv', 'backbone.C3_p4.m[0].conv1.conv', 'backbone.C3_p4.m[0].conv2.conv', 'backbone.reduce_conv1.conv', 'backbone.bu_conv2.conv', 'backbone.bu_conv1.conv']

# %%
value = list(dict.values())
value
# Out:
# [[0, 22, 23, 24, 25, 26, 30, 31, 37, 42],
#  [6, 20, 26, 29, 30, 31, 34, 37, 38, 41],
#  [1,
#   8,
#   12,
#   15,
#   17,
#   18,
#   21,
#   29,
#   34,
#   37,
#   51,
#   55,
#   65,
#   66,
#   67,
#   70,
#   79,
#   81,
#   90,
#   95],
#  [4, 14, 18, 21, 27, 36, 37, 38, 41, 43],
#  [1, 11, 12, 16, 18, 23, 26, 33, 38, 42],
#  [2, 12, 15, 27, 29, 30, 33, 34, 36, 40],
#  [4,
#   9,
#   17,
#   19,
#   23,
#   24,
#   25,
#   26,
#   31,
#   46,
#   59,
#   63,
#   64,
#   66,
#   72,
#   75,
#   80,
#   84,
#   85,
#   89],
#  [1, 2, 9, 14, 19, 26, 35, 39, 42, 43, 48, 56, 72, 74, 75, 84, 85, 86, 92, 94],
#  [4,
#   5,
#   10,
#   19,
#   20,
#   21,
#   34,
#   39,
#   41,
#   45,
#   63,
#   64,
#   72,
#   83,
#   84,
#   89,
#   95,
#   99,
#   101,
#   102,
#   103,
#   106,
#   113,
#   118,
#   120,
#   122,
#   132,
#   148,
#   149,
#   151,
#   152,
#   162,
#   168,
#   170,
#   172,
#   177,
#   181,
#   183,
#   186,
#   188],
#  [0,
#   20,
#   22,
#   37,
#   39,
#   40,
#   41,
#   47,
#   49,
#   53,
#   54,
#   60,
#   62,
#   63,
#   71,
#   72,
#   73,
#   75,
#   91,
#   93],
#  [18,
#   27,
#   29,
#   33,
#   40,
#   41,
#   43,
#   44,
#   47,
#   48,
#   50,
#   54,
#   56,
#   58,
#   60,
#   68,
#   84,
#   93,
#   94,
#   95],
#  [6,
#   11,
#   16,
#   17,
#   20,
#   23,
#   28,
#   33,
#   35,
#   38,
#   40,
#   47,
#   50,
#   55,
#   71,
#   78,
#   88,
#   89,
#   90,
#   92],
#  [1,
#   6,
#   10,
#   11,
#   16,
#   19,
#   21,
#   28,
#   29,
#   30,
#   32,
#   33,
#   41,
#   45,
#   50,
#   52,
#   63,
#   74,
#   81,
#   83,
#   87,
#   90,
#   91,
#   93,
#   103,
#   104,
#   111,
#   113,
#   117,
#   131,
#   132,
#   140,
#   141,
#   154,
#   158,
#   165,
#   169,
#   176,
#   179,
#   187],
#  [2,
#   12,
#   13,
#   16,
#   25,
#   29,
#   30,
#   33,
#   34,
#   45,
#   46,
#   49,
#   51,
#   55,
#   61,
#   65,
#   67,
#   74,
#   77,
#   78,
#   106,
#   109,
#   126,
#   127,
#   136,
#   138,
#   139,
#   152,
#   158,
#   160,
#   161,
#   164,
#   166,
#   168,
#   170,
#   171,
#   173,
#   174,
#   186,
#   188],
#  [3,
#   5,
#   18,
#   19,
#   21,
#   30,
#   42,
#   44,
#   45,
#   56,
#   60,
#   73,
#   74,
#   78,
#   79,
#   80,
#   82,
#   85,
#   86,
#   96,
#   97,
#   101,
#   102,
#   114,
#   117,
#   126,
#   129,
#   132,
#   143,
#   151,
#   159,
#   161,
#   165,
#   170,
#   175,
#   181,
#   183,
#   186,
#   193,
#   195,
#   196,
#   201,
#   202,
#   218,
#   222,
#   240,
#   242,
#   245,
#   248,
#   252,
#   253,
#   257,
#   258,
#   259,
#   264,
#   269,
#   273,
#   278,
#   283,
#   285,
#   297,
#   301,
#   310,
#   317,
#   328,
#   333,
#   335,
#   338,
#   339,
#   344,
#   345,
#   347,
#   350,
#   355,
#   357,
#   362,
#   371,
#   375,
#   378,
#   382],
#  [1,
#   4,
#   7,
#   10,
#   11,
#   15,
#   25,
#   36,
#   37,
#   47,
#   51,
#   58,
#   61,
#   70,
#   75,
#   82,
#   83,
#   85,
#   88,
#   97,
#   100,
#   103,
#   105,
#   107,
#   115,
#   125,
#   127,
#   129,
#   132,
#   136,
#   145,
#   150,
#   156,
#   158,
#   164,
#   168,
#   169,
#   178,
#   180,
#   184],
#  [4,
#   9,
#   10,
#   18,
#   19,
#   23,
#   27,
#   31,
#   38,
#   39,
#   55,
#   63,
#   71,
#   77,
#   88,
#   90,
#   92,
#   99,
#   103,
#   109,
#   113,
#   115,
#   119,
#   126,
#   127,
#   130,
#   132,
#   138,
#   139,
#   148,
#   155,
#   158,
#   165,
#   175,
#   179,
#   180,
#   182,
#   183,
#   184,
#   190],
#  [10,
#   16,
#   17,
#   18,
#   32,
#   35,
#   51,
#   53,
#   54,
#   63,
#   69,
#   73,
#   74,
#   81,
#   84,
#   102,
#   104,
#   107,
#   111,
#   120,
#   121,
#   133,
#   137,
#   139,
#   140,
#   142,
#   144,
#   146,
#   155,
#   162,
#   164,
#   172,
#   175,
#   176,
#   178,
#   181,
#   182,
#   184,
#   185,
#   186],
#  [12,
#   15,
#   17,
#   35,
#   36,
#   37,
#   38,
#   42,
#   46,
#   56,
#   58,
#   66,
#   70,
#   73,
#   82,
#   84,
#   85,
#   86,
#   88,
#   95],
#  [10,
#   13,
#   15,
#   16,
#   26,
#   28,
#   41,
#   44,
#   45,
#   47,
#   48,
#   57,
#   59,
#   65,
#   66,
#   70,
#   76,
#   81,
#   87,
#   95],
#  [1,
#   3,
#   16,
#   21,
#   29,
#   37,
#   44,
#   47,
#   58,
#   59,
#   62,
#   67,
#   68,
#   71,
#   77,
#   78,
#   80,
#   85,
#   86,
#   90,
#   91,
#   93,
#   103,
#   107,
#   113,
#   124,
#   133,
#   139,
#   140,
#   147,
#   158,
#   160,
#   163,
#   167,
#   176,
#   180,
#   182,
#   184,
#   186,
#   188],
#  [3, 6, 9, 13, 17, 23, 47, 52, 53, 57, 61, 66, 67, 77, 81, 82, 89, 90, 92, 94],
#  [6,
#   11,
#   19,
#   22,
#   24,
#   27,
#   28,
#   44,
#   57,
#   60,
#   63,
#   66,
#   67,
#   74,
#   76,
#   79,
#   80,
#   81,
#   88,
#   95],
#  [0,
#   5,
#   16,
#   20,
#   22,
#   31,
#   34,
#   40,
#   46,
#   51,
#   54,
#   61,
#   68,
#   73,
#   76,
#   77,
#   78,
#   79,
#   89,
#   92],
#  [0, 2, 5, 12, 13, 14, 19, 22, 26, 33, 41, 43, 52, 54, 56, 63, 66, 82, 85, 87],
#  [11,
#   14,
#   16,
#   18,
#   26,
#   28,
#   29,
#   30,
#   40,
#   42,
#   43,
#   48,
#   49,
#   54,
#   60,
#   64,
#   73,
#   76,
#   83,
#   94,
#   96,
#   100,
#   105,
#   106,
#   117,
#   122,
#   123,
#   138,
#   145,
#   149,
#   164,
#   166,
#   172,
#   175,
#   176,
#   179,
#   180,
#   182,
#   184,
#   189]]

# %%
for i in range(len(temp)):
    pruning_plan = DG.get_pruning_plan(eval(f"model.{temp[i]}"), tp.prune_conv_out_channel, value[i])
    print(pruning_plan)
    if DG.check_pruning_plan(pruning_plan):
        pruning_plan.exec()
# Out:
# Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv1.conv (Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.conv1.conv (Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={'#params': 960}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv1.conv (Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.0.conv1.conv (Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={'#params': 480}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.1.conv1.conv (Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={'#params': 480}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.2.conv1.conv (Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={'#params': 480}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConcatPruner on _ConcatOp([0, 48, 96]), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 48, 96]) => ConvInChannelPruner on backbone.backbone.dark3.1.conv3.conv (Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={'#params': 960}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark3.1.m.2.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.2.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.2.conv2.conv (Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={'#params': 4320}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark3.1.m.1.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.1.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.1.conv2.conv (Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={'#params': 4320}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark3.1.m.0.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.0.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.0.conv2.conv (Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[0, 22, 23, 24, 25, 26, 30, 31, 37, 42], metric={'#params': 4320}]
#
# Metric Sum: {'#params': 16400}
# --------------------------------
#
# Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv2.conv (Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.conv2.conv (Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[6, 20, 26, 29, 30, 31, 34, 37, 38, 41], metric={'#params': 960}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv2.conv (Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[6, 20, 26, 29, 30, 31, 34, 37, 38, 41], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.conv2.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[6, 20, 26, 29, 30, 31, 34, 37, 38, 41], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 38, 86]), Index=[44, 58, 64, 67, 68, 69, 72, 75, 76, 79], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 38, 86]) => ConvInChannelPruner on backbone.backbone.dark3.1.conv3.conv (Conv2d(86, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[44, 58, 64, 67, 68, 69, 72, 75, 76, 79], metric={'#params': 960}]
#
# Metric Sum: {'#params': 1940}
# --------------------------------
#
# Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv3.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.conv3.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 8, 12, 15, 17, 18, 21, 29, 34, 37, 51, 55, 65, 66, 67, 70, 79, 81, 90, 95], metric={'#params': 1520}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv3.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.conv3.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 8, 12, 15, 17, 18, 21, 29, 34, 37, 51, 55, 65, 66, 67, 70, 79, 81, 90, 95], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.conv3.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 8, 12, 15, 17, 18, 21, 29, 34, 37, 51, 55, 65, 66, 67, 70, 79, 81, 90, 95], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark4.0.conv (Conv2d(96, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), Index=[1, 8, 12, 15, 17, 18, 21, 29, 34, 37, 51, 55, 65, 66, 67, 70, 79, 81, 90, 95], metric={'#params': 34560}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 96, 192]), Index=[97, 104, 108, 111, 113, 114, 117, 125, 130, 133, 147, 151, 161, 162, 163, 166, 175, 177, 186, 191], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 192]) => ConvInChannelPruner on backbone.C3_p3.conv2.conv (Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[97, 104, 108, 111, 113, 114, 117, 125, 130, 133, 147, 151, 161, 162, 163, 166, 175, 177, 186, 191], metric={'#params': 960}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 192]) => ConvInChannelPruner on backbone.C3_p3.conv1.conv (Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[97, 104, 108, 111, 113, 114, 117, 125, 130, 133, 147, 151, 161, 162, 163, 166, 175, 177, 186, 191], metric={'#params': 960}]
#
# Metric Sum: {'#params': 38040}
# --------------------------------
#
# Conv2d(38, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.0.conv1.conv (Conv2d(38, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.0.conv1.conv (Conv2d(38, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 14, 18, 21, 27, 36, 37, 38, 41, 43], metric={'#params': 380}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.0.conv1.conv (Conv2d(38, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.m.0.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[4, 14, 18, 21, 27, 36, 37, 38, 41, 43], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.0.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[4, 14, 18, 21, 27, 36, 37, 38, 41, 43], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.0.conv2.conv (Conv2d(48, 38, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[4, 14, 18, 21, 27, 36, 37, 38, 41, 43], metric={'#params': 3420}]
#
# Metric Sum: {'#params': 3820}
# --------------------------------
#
# Conv2d(38, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.1.conv1.conv (Conv2d(38, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.1.conv1.conv (Conv2d(38, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 11, 12, 16, 18, 23, 26, 33, 38, 42], metric={'#params': 380}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.1.conv1.conv (Conv2d(38, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.m.1.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 11, 12, 16, 18, 23, 26, 33, 38, 42], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.1.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 11, 12, 16, 18, 23, 26, 33, 38, 42], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.1.conv2.conv (Conv2d(48, 38, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[1, 11, 12, 16, 18, 23, 26, 33, 38, 42], metric={'#params': 3420}]
#
# Metric Sum: {'#params': 3820}
# --------------------------------
#
# Conv2d(38, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.2.conv1.conv (Conv2d(38, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.2.conv1.conv (Conv2d(38, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[2, 12, 15, 27, 29, 30, 33, 34, 36, 40], metric={'#params': 380}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.2.conv1.conv (Conv2d(38, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.m.2.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[2, 12, 15, 27, 29, 30, 33, 34, 36, 40], metric={'#params': 20}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.2.conv1.bn (BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[2, 12, 15, 27, 29, 30, 33, 34, 36, 40], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.2.conv2.conv (Conv2d(48, 38, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[2, 12, 15, 27, 29, 30, 33, 34, 36, 40], metric={'#params': 3420}]
#
# Metric Sum: {'#params': 3820}
# --------------------------------
#
# Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv1.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.conv1.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={'#params': 3840}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv1.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.0.conv1.conv (Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={'#params': 1920}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.1.conv1.conv (Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={'#params': 1920}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.2.conv1.conv (Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={'#params': 1920}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConcatPruner on _ConcatOp([0, 96, 192]), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 192]) => ConvInChannelPruner on backbone.backbone.dark4.1.conv3.conv (Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={'#params': 3840}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark4.1.m.2.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.2.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.2.conv2.conv (Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={'#params': 17280}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark4.1.m.1.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.1.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.1.conv2.conv (Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={'#params': 17280}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark4.1.m.0.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.0.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.0.conv2.conv (Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[4, 9, 17, 19, 23, 24, 25, 26, 31, 46, 59, 63, 64, 66, 72, 75, 80, 84, 85, 89], metric={'#params': 17280}]
#
# Metric Sum: {'#params': 65440}
# --------------------------------
#
# Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv2.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.conv2.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 2, 9, 14, 19, 26, 35, 39, 42, 43, 48, 56, 72, 74, 75, 84, 85, 86, 92, 94], metric={'#params': 3840}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv2.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 2, 9, 14, 19, 26, 35, 39, 42, 43, 48, 56, 72, 74, 75, 84, 85, 86, 92, 94], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 2, 9, 14, 19, 26, 35, 39, 42, 43, 48, 56, 72, 74, 75, 84, 85, 86, 92, 94], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 76, 172]), Index=[77, 78, 85, 90, 95, 102, 111, 115, 118, 119, 124, 132, 148, 150, 151, 160, 161, 162, 168, 170], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 76, 172]) => ConvInChannelPruner on backbone.backbone.dark4.1.conv3.conv (Conv2d(172, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[77, 78, 85, 90, 95, 102, 111, 115, 118, 119, 124, 132, 148, 150, 151, 160, 161, 162, 168, 170], metric={'#params': 3840}]
#
# Metric Sum: {'#params': 7720}
# --------------------------------
#
# Conv2d(152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv3.conv (Conv2d(152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.conv3.conv (Conv2d(152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 5, 10, 19, 20, 21, 34, 39, 41, 45, 63, 64, 72, 83, 84, 89, 95, 99, 101, 102, 103, 106, 113, 118, 120, 122, 132, 148, 149, 151, 152, 162, 168, 170, 172, 177, 181, 183, 186, 188], metric={'#params': 6080}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv3.conv (Conv2d(152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.conv3.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[4, 5, 10, 19, 20, 21, 34, 39, 41, 45, 63, 64, 72, 83, 84, 89, 95, 99, 101, 102, 103, 106, 113, 118, 120, 122, 132, 148, 149, 151, 152, 162, 168, 170, 172, 177, 181, 183, 186, 188], metric={'#params': 80}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.conv3.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[4, 5, 10, 19, 20, 21, 34, 39, 41, 45, 63, 64, 72, 83, 84, 89, 95, 99, 101, 102, 103, 106, 113, 118, 120, 122, 132, 148, 149, 151, 152, 162, 168, 170, 172, 177, 181, 183, 186, 188], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark5.0.conv (Conv2d(192, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), Index=[4, 5, 10, 19, 20, 21, 34, 39, 41, 45, 63, 64, 72, 83, 84, 89, 95, 99, 101, 102, 103, 106, 113, 118, 120, 122, 132, 148, 149, 151, 152, 162, 168, 170, 172, 177, 181, 183, 186, 188], metric={'#params': 138240}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 192, 384]), Index=[196, 197, 202, 211, 212, 213, 226, 231, 233, 237, 255, 256, 264, 275, 276, 281, 287, 291, 293, 294, 295, 298, 305, 310, 312, 314, 324, 340, 341, 343, 344, 354, 360, 362, 364, 369, 373, 375, 378, 380], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 384]) => ConvInChannelPruner on backbone.C3_p4.conv2.conv (Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[196, 197, 202, 211, 212, 213, 226, 231, 233, 237, 255, 256, 264, 275, 276, 281, 287, 291, 293, 294, 295, 298, 305, 310, 312, 314, 324, 340, 341, 343, 344, 354, 360, 362, 364, 369, 373, 375, 378, 380], metric={'#params': 3840}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 384]) => ConvInChannelPruner on backbone.C3_p4.conv1.conv (Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[196, 197, 202, 211, 212, 213, 226, 231, 233, 237, 255, 256, 264, 275, 276, 281, 287, 291, 293, 294, 295, 298, 305, 310, 312, 314, 324, 340, 341, 343, 344, 354, 360, 362, 364, 369, 373, 375, 378, 380], metric={'#params': 3840}]
#
# Metric Sum: {'#params': 152080}
# --------------------------------
#
# Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.0.conv1.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.0.conv1.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 20, 22, 37, 39, 40, 41, 47, 49, 53, 54, 60, 62, 63, 71, 72, 73, 75, 91, 93], metric={'#params': 1520}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.0.conv1.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.m.0.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 20, 22, 37, 39, 40, 41, 47, 49, 53, 54, 60, 62, 63, 71, 72, 73, 75, 91, 93], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.0.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 20, 22, 37, 39, 40, 41, 47, 49, 53, 54, 60, 62, 63, 71, 72, 73, 75, 91, 93], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.0.conv2.conv (Conv2d(96, 76, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[0, 20, 22, 37, 39, 40, 41, 47, 49, 53, 54, 60, 62, 63, 71, 72, 73, 75, 91, 93], metric={'#params': 13680}]
#
# Metric Sum: {'#params': 15240}
# --------------------------------
#
# Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.1.conv1.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.1.conv1.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[18, 27, 29, 33, 40, 41, 43, 44, 47, 48, 50, 54, 56, 58, 60, 68, 84, 93, 94, 95], metric={'#params': 1520}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.1.conv1.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.m.1.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[18, 27, 29, 33, 40, 41, 43, 44, 47, 48, 50, 54, 56, 58, 60, 68, 84, 93, 94, 95], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.1.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[18, 27, 29, 33, 40, 41, 43, 44, 47, 48, 50, 54, 56, 58, 60, 68, 84, 93, 94, 95], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.1.conv2.conv (Conv2d(96, 76, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[18, 27, 29, 33, 40, 41, 43, 44, 47, 48, 50, 54, 56, 58, 60, 68, 84, 93, 94, 95], metric={'#params': 13680}]
#
# Metric Sum: {'#params': 15240}
# --------------------------------
#
# Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.2.conv1.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.2.conv1.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[6, 11, 16, 17, 20, 23, 28, 33, 35, 38, 40, 47, 50, 55, 71, 78, 88, 89, 90, 92], metric={'#params': 1520}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.2.conv1.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.m.2.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[6, 11, 16, 17, 20, 23, 28, 33, 35, 38, 40, 47, 50, 55, 71, 78, 88, 89, 90, 92], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.2.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[6, 11, 16, 17, 20, 23, 28, 33, 35, 38, 40, 47, 50, 55, 71, 78, 88, 89, 90, 92], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.2.conv2.conv (Conv2d(96, 76, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[6, 11, 16, 17, 20, 23, 28, 33, 35, 38, 40, 47, 50, 55, 71, 78, 88, 89, 90, 92], metric={'#params': 13680}]
#
# Metric Sum: {'#params': 15240}
# --------------------------------
#
# Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv1.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark5.2.conv1.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 6, 10, 11, 16, 19, 21, 28, 29, 30, 32, 33, 41, 45, 50, 52, 63, 74, 81, 83, 87, 90, 91, 93, 103, 104, 111, 113, 117, 131, 132, 140, 141, 154, 158, 165, 169, 176, 179, 187], metric={'#params': 15360}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv1.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark5.2.conv1.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 6, 10, 11, 16, 19, 21, 28, 29, 30, 32, 33, 41, 45, 50, 52, 63, 74, 81, 83, 87, 90, 91, 93, 103, 104, 111, 113, 117, 131, 132, 140, 141, 154, 158, 165, 169, 176, 179, 187], metric={'#params': 80}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark5.2.conv1.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 6, 10, 11, 16, 19, 21, 28, 29, 30, 32, 33, 41, 45, 50, 52, 63, 74, 81, 83, 87, 90, 91, 93, 103, 104, 111, 113, 117, 131, 132, 140, 141, 154, 158, 165, 169, 176, 179, 187], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark5.2.m.0.conv1.conv (Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 6, 10, 11, 16, 19, 21, 28, 29, 30, 32, 33, 41, 45, 50, 52, 63, 74, 81, 83, 87, 90, 91, 93, 103, 104, 111, 113, 117, 131, 132, 140, 141, 154, 158, 165, 169, 176, 179, 187], metric={'#params': 7680}]
#
# Metric Sum: {'#params': 23120}
# --------------------------------
#
# Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv2.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark5.2.conv2.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[2, 12, 13, 16, 25, 29, 30, 33, 34, 45, 46, 49, 51, 55, 61, 65, 67, 74, 77, 78, 106, 109, 126, 127, 136, 138, 139, 152, 158, 160, 161, 164, 166, 168, 170, 171, 173, 174, 186, 188], metric={'#params': 15360}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv2.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark5.2.conv2.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[2, 12, 13, 16, 25, 29, 30, 33, 34, 45, 46, 49, 51, 55, 61, 65, 67, 74, 77, 78, 106, 109, 126, 127, 136, 138, 139, 152, 158, 160, 161, 164, 166, 168, 170, 171, 173, 174, 186, 188], metric={'#params': 80}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark5.2.conv2.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[2, 12, 13, 16, 25, 29, 30, 33, 34, 45, 46, 49, 51, 55, 61, 65, 67, 74, 77, 78, 106, 109, 126, 127, 136, 138, 139, 152, 158, 160, 161, 164, 166, 168, 170, 171, 173, 174, 186, 188], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 192, 384]), Index=[194, 204, 205, 208, 217, 221, 222, 225, 226, 237, 238, 241, 243, 247, 253, 257, 259, 266, 269, 270, 298, 301, 318, 319, 328, 330, 331, 344, 350, 352, 353, 356, 358, 360, 362, 363, 365, 366, 378, 380], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 384]) => ConvInChannelPruner on backbone.backbone.dark5.2.conv3.conv (Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[194, 204, 205, 208, 217, 221, 222, 225, 226, 237, 238, 241, 243, 247, 253, 257, 259, 266, 269, 270, 298, 301, 318, 319, 328, 330, 331, 344, 350, 352, 353, 356, 358, 360, 362, 363, 365, 366, 378, 380], metric={'#params': 15360}]
#
# Metric Sum: {'#params': 30800}
# --------------------------------
#
# Conv2d(344, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv3.conv (Conv2d(344, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark5.2.conv3.conv (Conv2d(344, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[3, 5, 18, 19, 21, 30, 42, 44, 45, 56, 60, 73, 74, 78, 79, 80, 82, 85, 86, 96, 97, 101, 102, 114, 117, 126, 129, 132, 143, 151, 159, 161, 165, 170, 175, 181, 183, 186, 193, 195, 196, 201, 202, 218, 222, 240, 242, 245, 248, 252, 253, 257, 258, 259, 264, 269, 273, 278, 283, 285, 297, 301, 310, 317, 328, 333, 335, 338, 339, 344, 345, 347, 350, 355, 357, 362, 371, 375, 378, 382], metric={'#params': 27520}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv3.conv (Conv2d(344, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark5.2.conv3.bn (BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[3, 5, 18, 19, 21, 30, 42, 44, 45, 56, 60, 73, 74, 78, 79, 80, 82, 85, 86, 96, 97, 101, 102, 114, 117, 126, 129, 132, 143, 151, 159, 161, 165, 170, 175, 181, 183, 186, 193, 195, 196, 201, 202, 218, 222, 240, 242, 245, 248, 252, 253, 257, 258, 259, 264, 269, 273, 278, 283, 285, 297, 301, 310, 317, 328, 333, 335, 338, 339, 344, 345, 347, 350, 355, 357, 362, 371, 375, 378, 382], metric={'#params': 160}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark5.2.conv3.bn (BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[3, 5, 18, 19, 21, 30, 42, 44, 45, 56, 60, 73, 74, 78, 79, 80, 82, 85, 86, 96, 97, 101, 102, 114, 117, 126, 129, 132, 143, 151, 159, 161, 165, 170, 175, 181, 183, 186, 193, 195, 196, 201, 202, 218, 222, 240, 242, 245, 248, 252, 253, 257, 258, 259, 264, 269, 273, 278, 283, 285, 297, 301, 310, 317, 328, 333, 335, 338, 339, 344, 345, 347, 350, 355, 357, 362, 371, 375, 378, 382], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.lateral_conv0.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[3, 5, 18, 19, 21, 30, 42, 44, 45, 56, 60, 73, 74, 78, 79, 80, 82, 85, 86, 96, 97, 101, 102, 114, 117, 126, 129, 132, 143, 151, 159, 161, 165, 170, 175, 181, 183, 186, 193, 195, 196, 201, 202, 218, 222, 240, 242, 245, 248, 252, 253, 257, 258, 259, 264, 269, 273, 278, 283, 285, 297, 301, 310, 317, 328, 333, 335, 338, 339, 344, 345, 347, 350, 355, 357, 362, 371, 375, 378, 382], metric={'#params': 15360}]
#
# Metric Sum: {'#params': 43040}
# --------------------------------
#
# Conv2d(152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv1.conv (Conv2d(152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv1.conv (Conv2d(152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 4, 7, 10, 11, 15, 25, 36, 37, 47, 51, 58, 61, 70, 75, 82, 83, 85, 88, 97, 100, 103, 105, 107, 115, 125, 127, 129, 132, 136, 145, 150, 156, 158, 164, 168, 169, 178, 180, 184], metric={'#params': 6080}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv1.conv (Conv2d(152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark5.2.m.0.conv1.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 4, 7, 10, 11, 15, 25, 36, 37, 47, 51, 58, 61, 70, 75, 82, 83, 85, 88, 97, 100, 103, 105, 107, 115, 125, 127, 129, 132, 136, 145, 150, 156, 158, 164, 168, 169, 178, 180, 184], metric={'#params': 80}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark5.2.m.0.conv1.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 4, 7, 10, 11, 15, 25, 36, 37, 47, 51, 58, 61, 70, 75, 82, 83, 85, 88, 97, 100, 103, 105, 107, 115, 125, 127, 129, 132, 136, 145, 150, 156, 158, 164, 168, 169, 178, 180, 184], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark5.2.m.0.conv2.conv (Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[1, 4, 7, 10, 11, 15, 25, 36, 37, 47, 51, 58, 61, 70, 75, 82, 83, 85, 88, 97, 100, 103, 105, 107, 115, 125, 127, 129, 132, 136, 145, 150, 156, 158, 164, 168, 169, 178, 180, 184], metric={'#params': 69120}]
#
# Metric Sum: {'#params': 75280}
# --------------------------------
#
# Conv2d(152, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv2.conv (Conv2d(152, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv2.conv (Conv2d(152, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[4, 9, 10, 18, 19, 23, 27, 31, 38, 39, 55, 63, 71, 77, 88, 90, 92, 99, 103, 109, 113, 115, 119, 126, 127, 130, 132, 138, 139, 148, 155, 158, 165, 175, 179, 180, 182, 183, 184, 190], metric={'#params': 54720}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv2.conv (Conv2d(152, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark5.2.m.0.conv2.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[4, 9, 10, 18, 19, 23, 27, 31, 38, 39, 55, 63, 71, 77, 88, 90, 92, 99, 103, 109, 113, 115, 119, 126, 127, 130, 132, 138, 139, 148, 155, 158, 165, 175, 179, 180, 182, 183, 184, 190], metric={'#params': 80}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark5.2.m.0.conv2.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[4, 9, 10, 18, 19, 23, 27, 31, 38, 39, 55, 63, 71, 77, 88, 90, 92, 99, 103, 109, 113, 115, 119, 126, 127, 130, 132, 138, 139, 148, 155, 158, 165, 175, 179, 180, 182, 183, 184, 190], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 192, 344]), Index=[4, 9, 10, 18, 19, 23, 27, 31, 38, 39, 55, 63, 71, 77, 88, 90, 92, 99, 103, 109, 113, 115, 119, 126, 127, 130, 132, 138, 139, 148, 155, 158, 165, 175, 179, 180, 182, 183, 184, 190], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 344]) => ConvInChannelPruner on backbone.backbone.dark5.2.conv3.conv (Conv2d(344, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 9, 10, 18, 19, 23, 27, 31, 38, 39, 55, 63, 71, 77, 88, 90, 92, 99, 103, 109, 113, 115, 119, 126, 127, 130, 132, 138, 139, 148, 155, 158, 165, 175, 179, 180, 182, 183, 184, 190], metric={'#params': 12160}]
#
# Metric Sum: {'#params': 66960}
# --------------------------------
#
# Conv2d(304, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.lateral_conv0.conv (Conv2d(304, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.lateral_conv0.conv (Conv2d(304, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[10, 16, 17, 18, 32, 35, 51, 53, 54, 63, 69, 73, 74, 81, 84, 102, 104, 107, 111, 120, 121, 133, 137, 139, 140, 142, 144, 146, 155, 162, 164, 172, 175, 176, 178, 181, 182, 184, 185, 186], metric={'#params': 12160}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.lateral_conv0.conv (Conv2d(304, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.lateral_conv0.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[10, 16, 17, 18, 32, 35, 51, 53, 54, 63, 69, 73, 74, 81, 84, 102, 104, 107, 111, 120, 121, 133, 137, 139, 140, 142, 144, 146, 155, 162, 164, 172, 175, 176, 178, 181, 182, 184, 185, 186], metric={'#params': 80}]
# [ [DEP] BatchnormPruner on backbone.lateral_conv0.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[10, 16, 17, 18, 32, 35, 51, 53, 54, 63, 69, 73, 74, 81, 84, 102, 104, 107, 111, 120, 121, 133, 137, 139, 140, 142, 144, 146, 155, 162, 164, 172, 175, 176, 178, 181, 182, 184, 185, 186], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 192, 384]), Index=[202, 208, 209, 210, 224, 227, 243, 245, 246, 255, 261, 265, 266, 273, 276, 294, 296, 299, 303, 312, 313, 325, 329, 331, 332, 334, 336, 338, 347, 354, 356, 364, 367, 368, 370, 373, 374, 376, 377, 378], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ElementWiseOpPruner on _ElementWiseOp(UpsampleNearest2DBackward1), Index=[10, 16, 17, 18, 32, 35, 51, 53, 54, 63, 69, 73, 74, 81, 84, 102, 104, 107, 111, 120, 121, 133, 137, 139, 140, 142, 144, 146, 155, 162, 164, 172, 175, 176, 178, 181, 182, 184, 185, 186], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(UpsampleNearest2DBackward1) => ConcatPruner on _ConcatOp([0, 192, 344]), Index=[10, 16, 17, 18, 32, 35, 51, 53, 54, 63, 69, 73, 74, 81, 84, 102, 104, 107, 111, 120, 121, 133, 137, 139, 140, 142, 144, 146, 155, 162, 164, 172, 175, 176, 178, 181, 182, 184, 185, 186], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 344]) => ConvInChannelPruner on backbone.C3_p4.conv2.conv (Conv2d(344, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[10, 16, 17, 18, 32, 35, 51, 53, 54, 63, 69, 73, 74, 81, 84, 102, 104, 107, 111, 120, 121, 133, 137, 139, 140, 142, 144, 146, 155, 162, 164, 172, 175, 176, 178, 181, 182, 184, 185, 186], metric={'#params': 3840}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 344]) => ConvInChannelPruner on backbone.C3_p4.conv1.conv (Conv2d(344, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[10, 16, 17, 18, 32, 35, 51, 53, 54, 63, 69, 73, 74, 81, 84, 102, 104, 107, 111, 120, 121, 133, 137, 139, 140, 142, 144, 146, 155, 162, 164, 172, 175, 176, 178, 181, 182, 184, 185, 186], metric={'#params': 3840}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 384]) => ConvInChannelPruner on backbone.C3_n4.conv2.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[202, 208, 209, 210, 224, 227, 243, 245, 246, 255, 261, 265, 266, 273, 276, 294, 296, 299, 303, 312, 313, 325, 329, 331, 332, 334, 336, 338, 347, 354, 356, 364, 367, 368, 370, 373, 374, 376, 377, 378], metric={'#params': 7680}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 384]) => ConvInChannelPruner on backbone.C3_n4.conv1.conv (Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[202, 208, 209, 210, 224, 227, 243, 245, 246, 255, 261, 265, 266, 273, 276, 294, 296, 299, 303, 312, 313, 325, 329, 331, 332, 334, 336, 338, 347, 354, 356, 364, 367, 368, 370, 373, 374, 376, 377, 378], metric={'#params': 7680}]
#
# Metric Sum: {'#params': 35280}
# --------------------------------
#
# Conv2d(304, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.conv1.conv (Conv2d(304, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.C3_p4.conv1.conv (Conv2d(304, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[12, 15, 17, 35, 36, 37, 38, 42, 46, 56, 58, 66, 70, 73, 82, 84, 85, 86, 88, 95], metric={'#params': 6080}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.conv1.conv (Conv2d(304, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.C3_p4.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[12, 15, 17, 35, 36, 37, 38, 42, 46, 56, 58, 66, 70, 73, 82, 84, 85, 86, 88, 95], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.C3_p4.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[12, 15, 17, 35, 36, 37, 38, 42, 46, 56, 58, 66, 70, 73, 82, 84, 85, 86, 88, 95], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.C3_p4.m.0.conv1.conv (Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[12, 15, 17, 35, 36, 37, 38, 42, 46, 56, 58, 66, 70, 73, 82, 84, 85, 86, 88, 95], metric={'#params': 1920}]
#
# Metric Sum: {'#params': 8040}
# --------------------------------
#
# Conv2d(304, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.conv2.conv (Conv2d(304, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.C3_p4.conv2.conv (Conv2d(304, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[10, 13, 15, 16, 26, 28, 41, 44, 45, 47, 48, 57, 59, 65, 66, 70, 76, 81, 87, 95], metric={'#params': 6080}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.conv2.conv (Conv2d(304, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.C3_p4.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[10, 13, 15, 16, 26, 28, 41, 44, 45, 47, 48, 57, 59, 65, 66, 70, 76, 81, 87, 95], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.C3_p4.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[10, 13, 15, 16, 26, 28, 41, 44, 45, 47, 48, 57, 59, 65, 66, 70, 76, 81, 87, 95], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 96, 192]), Index=[106, 109, 111, 112, 122, 124, 137, 140, 141, 143, 144, 153, 155, 161, 162, 166, 172, 177, 183, 191], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 192]) => ConvInChannelPruner on backbone.C3_p4.conv3.conv (Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[106, 109, 111, 112, 122, 124, 137, 140, 141, 143, 144, 153, 155, 161, 162, 166, 172, 177, 183, 191], metric={'#params': 3840}]
#
# Metric Sum: {'#params': 9960}
# --------------------------------
#
# Conv2d(172, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.conv3.conv (Conv2d(172, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.C3_p4.conv3.conv (Conv2d(172, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 3, 16, 21, 29, 37, 44, 47, 58, 59, 62, 67, 68, 71, 77, 78, 80, 85, 86, 90, 91, 93, 103, 107, 113, 124, 133, 139, 140, 147, 158, 160, 163, 167, 176, 180, 182, 184, 186, 188], metric={'#params': 6880}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.conv3.conv (Conv2d(172, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.C3_p4.conv3.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 3, 16, 21, 29, 37, 44, 47, 58, 59, 62, 67, 68, 71, 77, 78, 80, 85, 86, 90, 91, 93, 103, 107, 113, 124, 133, 139, 140, 147, 158, 160, 163, 167, 176, 180, 182, 184, 186, 188], metric={'#params': 80}]
# [ [DEP] BatchnormPruner on backbone.C3_p4.conv3.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 3, 16, 21, 29, 37, 44, 47, 58, 59, 62, 67, 68, 71, 77, 78, 80, 85, 86, 90, 91, 93, 103, 107, 113, 124, 133, 139, 140, 147, 158, 160, 163, 167, 176, 180, 182, 184, 186, 188], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.reduce_conv1.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 3, 16, 21, 29, 37, 44, 47, 58, 59, 62, 67, 68, 71, 77, 78, 80, 85, 86, 90, 91, 93, 103, 107, 113, 124, 133, 139, 140, 147, 158, 160, 163, 167, 176, 180, 182, 184, 186, 188], metric={'#params': 3840}]
#
# Metric Sum: {'#params': 10800}
# --------------------------------
#
# Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.m.0.conv1.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.C3_p4.m.0.conv1.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[3, 6, 9, 13, 17, 23, 47, 52, 53, 57, 61, 66, 67, 77, 81, 82, 89, 90, 92, 94], metric={'#params': 1520}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.m.0.conv1.conv (Conv2d(76, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.C3_p4.m.0.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[3, 6, 9, 13, 17, 23, 47, 52, 53, 57, 61, 66, 67, 77, 81, 82, 89, 90, 92, 94], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.C3_p4.m.0.conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[3, 6, 9, 13, 17, 23, 47, 52, 53, 57, 61, 66, 67, 77, 81, 82, 89, 90, 92, 94], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.C3_p4.m.0.conv2.conv (Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[3, 6, 9, 13, 17, 23, 47, 52, 53, 57, 61, 66, 67, 77, 81, 82, 89, 90, 92, 94], metric={'#params': 17280}]
#
# Metric Sum: {'#params': 18840}
# --------------------------------
#
# Conv2d(76, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.m.0.conv2.conv (Conv2d(76, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.C3_p4.m.0.conv2.conv (Conv2d(76, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[6, 11, 19, 22, 24, 27, 28, 44, 57, 60, 63, 66, 67, 74, 76, 79, 80, 81, 88, 95], metric={'#params': 13680}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.C3_p4.m.0.conv2.conv (Conv2d(76, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => BatchnormPruner on backbone.C3_p4.m.0.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[6, 11, 19, 22, 24, 27, 28, 44, 57, 60, 63, 66, 67, 74, 76, 79, 80, 81, 88, 95], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.C3_p4.m.0.conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[6, 11, 19, 22, 24, 27, 28, 44, 57, 60, 63, 66, 67, 74, 76, 79, 80, 81, 88, 95], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 96, 172]), Index=[6, 11, 19, 22, 24, 27, 28, 44, 57, 60, 63, 66, 67, 74, 76, 79, 80, 81, 88, 95], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 172]) => ConvInChannelPruner on backbone.C3_p4.conv3.conv (Conv2d(172, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[6, 11, 19, 22, 24, 27, 28, 44, 57, 60, 63, 66, 67, 74, 76, 79, 80, 81, 88, 95], metric={'#params': 3040}]
#
# Metric Sum: {'#params': 16760}
# --------------------------------
#
# Conv2d(152, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.reduce_conv1.conv (Conv2d(152, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.reduce_conv1.conv (Conv2d(152, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 5, 16, 20, 22, 31, 34, 40, 46, 51, 54, 61, 68, 73, 76, 77, 78, 79, 89, 92], metric={'#params': 3040}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.reduce_conv1.conv (Conv2d(152, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.reduce_conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 5, 16, 20, 22, 31, 34, 40, 46, 51, 54, 61, 68, 73, 76, 77, 78, 79, 89, 92], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.reduce_conv1.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 5, 16, 20, 22, 31, 34, 40, 46, 51, 54, 61, 68, 73, 76, 77, 78, 79, 89, 92], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 96, 192]), Index=[96, 101, 112, 116, 118, 127, 130, 136, 142, 147, 150, 157, 164, 169, 172, 173, 174, 175, 185, 188], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ElementWiseOpPruner on _ElementWiseOp(UpsampleNearest2DBackward1), Index=[0, 5, 16, 20, 22, 31, 34, 40, 46, 51, 54, 61, 68, 73, 76, 77, 78, 79, 89, 92], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(UpsampleNearest2DBackward1) => ConcatPruner on _ConcatOp([0, 96, 172]), Index=[0, 5, 16, 20, 22, 31, 34, 40, 46, 51, 54, 61, 68, 73, 76, 77, 78, 79, 89, 92], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 172]) => ConvInChannelPruner on backbone.C3_p3.conv2.conv (Conv2d(172, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 5, 16, 20, 22, 31, 34, 40, 46, 51, 54, 61, 68, 73, 76, 77, 78, 79, 89, 92], metric={'#params': 960}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 172]) => ConvInChannelPruner on backbone.C3_p3.conv1.conv (Conv2d(172, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 5, 16, 20, 22, 31, 34, 40, 46, 51, 54, 61, 68, 73, 76, 77, 78, 79, 89, 92], metric={'#params': 960}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 192]) => ConvInChannelPruner on backbone.C3_n3.conv2.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[96, 101, 112, 116, 118, 127, 130, 136, 142, 147, 150, 157, 164, 169, 172, 173, 174, 175, 185, 188], metric={'#params': 1920}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 192]) => ConvInChannelPruner on backbone.C3_n3.conv1.conv (Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[96, 101, 112, 116, 118, 127, 130, 136, 142, 147, 150, 157, 164, 169, 172, 173, 174, 175, 185, 188], metric={'#params': 1920}]
#
# Metric Sum: {'#params': 8840}
# --------------------------------
#
# Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.bu_conv2.conv (Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.bu_conv2.conv (Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), Index=[0, 2, 5, 12, 13, 14, 19, 22, 26, 33, 41, 43, 52, 54, 56, 63, 66, 82, 85, 87], metric={'#params': 17280}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.bu_conv2.conv (Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => BatchnormPruner on backbone.bu_conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 2, 5, 12, 13, 14, 19, 22, 26, 33, 41, 43, 52, 54, 56, 63, 66, 82, 85, 87], metric={'#params': 40}]
# [ [DEP] BatchnormPruner on backbone.bu_conv2.bn (BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 2, 5, 12, 13, 14, 19, 22, 26, 33, 41, 43, 52, 54, 56, 63, 66, 82, 85, 87], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 96, 172]), Index=[0, 2, 5, 12, 13, 14, 19, 22, 26, 33, 41, 43, 52, 54, 56, 63, 66, 82, 85, 87], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 172]) => ConvInChannelPruner on backbone.C3_n3.conv2.conv (Conv2d(172, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 2, 5, 12, 13, 14, 19, 22, 26, 33, 41, 43, 52, 54, 56, 63, 66, 82, 85, 87], metric={'#params': 1920}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 96, 172]) => ConvInChannelPruner on backbone.C3_n3.conv1.conv (Conv2d(172, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 2, 5, 12, 13, 14, 19, 22, 26, 33, 41, 43, 52, 54, 56, 63, 66, 82, 85, 87], metric={'#params': 1920}]
#
# Metric Sum: {'#params': 21160}
# --------------------------------
#
# Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.bu_conv1.conv (Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.bu_conv1.conv (Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), Index=[11, 14, 16, 18, 26, 28, 29, 30, 40, 42, 43, 48, 49, 54, 60, 64, 73, 76, 83, 94, 96, 100, 105, 106, 117, 122, 123, 138, 145, 149, 164, 166, 172, 175, 176, 179, 180, 182, 184, 189], metric={'#params': 69120}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.bu_conv1.conv (Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => BatchnormPruner on backbone.bu_conv1.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[11, 14, 16, 18, 26, 28, 29, 30, 40, 42, 43, 48, 49, 54, 60, 64, 73, 76, 83, 94, 96, 100, 105, 106, 117, 122, 123, 138, 145, 149, 164, 166, 172, 175, 176, 179, 180, 182, 184, 189], metric={'#params': 80}]
# [ [DEP] BatchnormPruner on backbone.bu_conv1.bn (BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[11, 14, 16, 18, 26, 28, 29, 30, 40, 42, 43, 48, 49, 54, 60, 64, 73, 76, 83, 94, 96, 100, 105, 106, 117, 122, 123, 138, 145, 149, 164, 166, 172, 175, 176, 179, 180, 182, 184, 189], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 192, 344]), Index=[11, 14, 16, 18, 26, 28, 29, 30, 40, 42, 43, 48, 49, 54, 60, 64, 73, 76, 83, 94, 96, 100, 105, 106, 117, 122, 123, 138, 145, 149, 164, 166, 172, 175, 176, 179, 180, 182, 184, 189], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 344]) => ConvInChannelPruner on backbone.C3_n4.conv2.conv (Conv2d(344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[11, 14, 16, 18, 26, 28, 29, 30, 40, 42, 43, 48, 49, 54, 60, 64, 73, 76, 83, 94, 96, 100, 105, 106, 117, 122, 123, 138, 145, 149, 164, 166, 172, 175, 176, 179, 180, 182, 184, 189], metric={'#params': 7680}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 192, 344]) => ConvInChannelPruner on backbone.C3_n4.conv1.conv (Conv2d(344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[11, 14, 16, 18, 26, 28, 29, 30, 40, 42, 43, 48, 49, 54, 60, 64, 73, 76, 83, 94, 96, 100, 105, 106, 117, 122, 123, 138, 145, 149, 164, 166, 172, 175, 176, 179, 180, 182, 184, 189], metric={'#params': 7680}]
#
# Metric Sum: {'#params': 84560}
# --------------------------------

# %%
print(model)
# Out:
# YOLOX(
#   (backbone): YOLOPAFPN(
#     (backbone): CSPDarknet(
#       (stem): Focus(
#         (conv): BaseConv(
#           (conv): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (dark2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(24, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark3): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(48, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(96, 38, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(38, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(96, 38, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(38, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(76, 76, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(38, 38, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(38, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(38, 38, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(38, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(38, 38, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(38, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(38, 38, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(38, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(38, 38, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(38, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(38, 38, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(38, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark4): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(76, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(192, 76, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(192, 76, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(152, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(152, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(76, 76, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(76, 76, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(76, 76, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(76, 76, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(76, 76, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(76, 76, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark5): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(152, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): SPPBottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): ModuleList(
#             (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#             (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#             (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(384, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(152, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(384, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(152, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(304, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(304, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(152, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(152, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(152, 152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(152, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (upsample): Upsample(scale_factor=2.0, mode=nearest)
#     (lateral_conv0): BaseConv(
#       (conv): Conv2d(304, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(152, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(304, 76, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(304, 76, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(152, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(152, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(76, 76, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(76, 76, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (reduce_conv1): BaseConv(
#       (conv): Conv2d(152, 76, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(152, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(152, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv2): BaseConv(
#       (conv): Conv2d(96, 76, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(76, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(152, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(152, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv1): BaseConv(
#       (conv): Conv2d(192, 152, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(152, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(304, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(304, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (head): YOLOXHead(
#     (cls_convs): ModuleList(
#       (0): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (reg_convs): ModuleList(
#       (0): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (cls_preds): ModuleList(
#       (0): Conv2d(96, 20, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 20, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 20, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (reg_preds): ModuleList(
#       (0): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (obj_preds): ModuleList(
#       (0): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stems): ModuleList(
#       (0): BaseConv(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): BaseConv(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): BaseConv(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (l1_loss): L1Loss()
#     (bcewithlog_loss): BCEWithLogitsLoss()
#     (iou_loss): IOUloss()
#   )
# )

# %%
ckpt_state = {
                "model": model.state_dict(),
            }

torch.save(ckpt_state, '0.2.pth')
