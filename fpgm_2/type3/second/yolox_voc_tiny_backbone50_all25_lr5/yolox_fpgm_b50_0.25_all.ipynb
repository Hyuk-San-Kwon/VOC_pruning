# %%
import torch
import torch_pruning as tp
from yolox.models import create_yolox_model

model = create_yolox_model(num_classes=20,name = 'yolox_custom',  
exp_path = '/workspace/tensorrt/YOLOX/exps/default/custom2/type3/all25_stem/yolox_voc_tiny_all25_stem_lr5.py',
ckpt_path = '/workspace/tensorrt/YOLOX/fpgm_2/type3/second/yolox_voc_tiny_all25_stem_lr5/37.64.pth'
).cuda()
# 1. setup strategy (L1 Norm)
strategy = tp.strategy.L1Strategy() # or tp.strategy.RandomStrategy()

# %%
# 2. build dependency graph for resnet18
DG = tp.DependencyGraph()
DG.build_dependency(model, example_inputs=torch.randn(1,3,224,224).cuda())

# %%
temp = []
temp2 = list(model.state_dict().keys())
num_list = [0,1,2,3]
#print(temp2)
for i in range(len(temp2)):
        if 'bn' in temp2[i]:
            continue
        if 'weight' in temp2[i]:
            temp2[i] = temp2[i].replace('.weight','')
            temp2[i] = temp2[i].replace('2.0','2[0]')
            temp2[i] = temp2[i].replace('2.1','2[1]')
            temp2[i] = temp2[i].replace('3.0','3[0]')
            temp2[i] = temp2[i].replace('3.1','3[1]')
            temp2[i] = temp2[i].replace('4.0','4[0]')
            temp2[i] = temp2[i].replace('4.1','4[1]')
            temp2[i] = temp2[i].replace('5.0','5[0]')
            temp2[i] = temp2[i].replace('5.1','5[1]')
            temp2[i] = temp2[i].replace('5.2','5[2]')
            temp2[i] = temp2[i].replace('m.0','m[0]')
            temp2[i] = temp2[i].replace('m.1','m[1]')
            temp2[i] = temp2[i].replace('m.2','m[2]')
            temp.append(temp2[i])

print(temp)
# backbone 만 프루닝
# Out:
# ['backbone.backbone.stem.conv.conv', 'backbone.backbone.dark2[0].conv', 'backbone.backbone.dark2[1].conv1.conv', 'backbone.backbone.dark2[1].conv2.conv', 'backbone.backbone.dark2[1].conv3.conv', 'backbone.backbone.dark2[1].m[0].conv1.conv', 'backbone.backbone.dark2[1].m[0].conv2.conv', 'backbone.backbone.dark3[0].conv', 'backbone.backbone.dark3[1].conv1.conv', 'backbone.backbone.dark3[1].conv2.conv', 'backbone.backbone.dark3[1].conv3.conv', 'backbone.backbone.dark3[1].m[0].conv1.conv', 'backbone.backbone.dark3[1].m[0].conv2.conv', 'backbone.backbone.dark3[1].m[1].conv1.conv', 'backbone.backbone.dark3[1].m[1].conv2.conv', 'backbone.backbone.dark3[1].m[2].conv1.conv', 'backbone.backbone.dark3[1].m[2].conv2.conv', 'backbone.backbone.dark4[0].conv', 'backbone.backbone.dark4[1].conv1.conv', 'backbone.backbone.dark4[1].conv2.conv', 'backbone.backbone.dark4[1].conv3.conv', 'backbone.backbone.dark4[1].m[0].conv1.conv', 'backbone.backbone.dark4[1].m[0].conv2.conv', 'backbone.backbone.dark4[1].m[1].conv1.conv', 'backbone.backbone.dark4[1].m[1].conv2.conv', 'backbone.backbone.dark4[1].m[2].conv1.conv', 'backbone.backbone.dark4[1].m[2].conv2.conv', 'backbone.backbone.dark5[0].conv', 'backbone.backbone.dark5[1].conv1.conv', 'backbone.backbone.dark5[1].conv2.conv', 'backbone.backbone.dark5[2].conv1.conv', 'backbone.backbone.dark5[2].conv2.conv', 'backbone.backbone.dark5[2].conv3.conv', 'backbone.backbone.dark5[2].m[0].conv1.conv', 'backbone.backbone.dark5[2].m[0].conv2.conv', 'backbone.lateral_conv0.conv', 'backbone.C3_p4.conv1.conv', 'backbone.C3_p4.conv2.conv', 'backbone.C3_p4.conv3.conv', 'backbone.C3_p4.m[0].conv1.conv', 'backbone.C3_p4.m[0].conv2.conv', 'backbone.reduce_conv1.conv', 'backbone.C3_p3.conv1.conv', 'backbone.C3_p3.conv2.conv', 'backbone.C3_p3.conv3.conv', 'backbone.C3_p3.m[0].conv1.conv', 'backbone.C3_p3.m[0].conv2.conv', 'backbone.bu_conv2.conv', 'backbone.C3_n3.conv1.conv', 'backbone.C3_n3.conv2.conv', 'backbone.C3_n3.conv3.conv', 'backbone.C3_n3.m[0].conv1.conv', 'backbone.C3_n3.m[0].conv2.conv', 'backbone.bu_conv1.conv', 'backbone.C3_n4.conv1.conv', 'backbone.C3_n4.conv2.conv', 'backbone.C3_n4.conv3.conv', 'backbone.C3_n4.m[0].conv1.conv', 'backbone.C3_n4.m[0].conv2.conv', 'head.cls_convs.0.0.conv', 'head.cls_convs.0.1.conv', 'head.cls_convs.1.0.conv', 'head.cls_convs.1.1.conv', 'head.cls_convs.2[0].conv', 'head.cls_convs.2[1].conv', 'head.reg_convs.0.0.conv', 'head.reg_convs.0.1.conv', 'head.reg_convs.1.0.conv', 'head.reg_convs.1.1.conv', 'head.reg_convs.2[0].conv', 'head.reg_convs.2[1].conv', 'head.cls_preds.0', 'head.cls_preds.1', 'head.cls_preds.2', 'head.reg_preds.0', 'head.reg_preds.1', 'head.reg_preds.2', 'head.obj_preds.0', 'head.obj_preds.1', 'head.obj_preds.2', 'head.stems.0.conv', 'head.stems.1.conv', 'head.stems.2.conv']

# %%
print(model)
# Out:
# YOLOX(
#   (backbone): YOLOPAFPN(
#     (backbone): CSPDarknet(
#       (stem): Focus(
#         (conv): BaseConv(
#           (conv): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (dark2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(24, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark3): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(48, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(96, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(96, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(36, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(36, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(36, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(36, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(36, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(36, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark4): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(72, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(192, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(192, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark5): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(144, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): SPPBottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): ModuleList(
#             (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#             (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#             (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(384, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(384, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(288, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (upsample): Upsample(scale_factor=2.0, mode=nearest)
#     (lateral_conv0): BaseConv(
#       (conv): Conv2d(288, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (reduce_conv1): BaseConv(
#       (conv): Conv2d(144, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(36, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(36, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv2): BaseConv(
#       (conv): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(144, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(144, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv1): BaseConv(
#       (conv): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(288, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(288, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (head): YOLOXHead(
#     (cls_convs): ModuleList(
#       (0): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(72, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(72, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(72, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (reg_convs): ModuleList(
#       (0): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(72, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(72, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(72, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (cls_preds): ModuleList(
#       (0): Conv2d(96, 20, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 20, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 20, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (reg_preds): ModuleList(
#       (0): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (obj_preds): ModuleList(
#       (0): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stems): ModuleList(
#       (0): BaseConv(
#         (conv): Conv2d(72, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): BaseConv(
#         (conv): Conv2d(144, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): BaseConv(
#         (conv): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (l1_loss): L1Loss()
#     (bcewithlog_loss): BCEWithLogitsLoss()
#     (iou_loss): IOUloss()
#   )
# )

# %%
from pruning_imagenet import Mask

# %%
m = Mask(model)
#m.mask_index = [24,27,33,39,45,54,57,63,69,75,90,93,99,102, ] # backbone conv3 30 60 96
                           # ,105,108,111,114,117,120,123,141,159] # neck

m.mask_index = [30 ,60 ,96 ,105,108,111,114,117,120,123,141,159,126,129,132,135,138,144,147,150,153,156,162,165,168,171,174, #neck
                            231,234,237, #stems
                            177,180,183,186,189,192,195,198,201,204,207,210] # head
m.mask_index = [24,27,33,39,45,54,57,63,69,75,90,93,99,102, ] # backbone conv3 30 60 96

# %%
m.init_length()

# %%
m.init_mask(1, 1/3)
print(m.mask_index)
# Out:
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# filter codebook done
# similar index done
# mask Ready
# [24, 27, 33, 39, 45, 54, 57, 63, 69, 75, 90, 93, 99, 102]

# %%
m.do_mask()
m.do_similar_mask()
# Out:
# mask Done
# mask similar Done

# %%
m.if_zero()
print(m.mask_index)
print(m.similar_matrix)
# Out:
# layer: 24, number of nonzero weight is 2304, zero is 1152
# layer: 27, number of nonzero weight is 2304, zero is 1152
# layer: 33, number of nonzero weight is 864, zero is 432
# layer: 39, number of nonzero weight is 864, zero is 432
# layer: 45, number of nonzero weight is 864, zero is 432
# layer: 54, number of nonzero weight is 9216, zero is 4608
# layer: 57, number of nonzero weight is 9216, zero is 4608
# layer: 63, number of nonzero weight is 3456, zero is 1728
# layer: 69, number of nonzero weight is 3456, zero is 1728
# layer: 75, number of nonzero weight is 3456, zero is 1728
# layer: 90, number of nonzero weight is 36864, zero is 18432
# layer: 93, number of nonzero weight is 36864, zero is 18432
# layer: 99, number of nonzero weight is 13824, zero is 6912
# layer: 102, number of nonzero weight is 124416, zero is 62208
# [24, 27, 33, 39, 45, 54, 57, 63, 69, 75, 90, 93, 99, 102]
# {24: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 27: tensor([0., 0., 0.,  ..., 1., 1., 1.], device='cuda:0'), 33: tensor([0., 0., 0.,  ..., 1., 1., 1.], device='cuda:0'), 39: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 45: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 54: tensor([1., 1., 1.,  ..., 0., 0., 0.], device='cuda:0'), 57: tensor([0., 0., 0.,  ..., 1., 1., 1.], device='cuda:0'), 63: tensor([1., 1., 1.,  ..., 0., 0., 0.], device='cuda:0'), 69: tensor([0., 0., 0.,  ..., 1., 1., 1.], device='cuda:0'), 75: tensor([1., 1., 1.,  ..., 0., 0., 0.], device='cuda:0'), 90: tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'), 93: tensor([0., 0., 0.,  ..., 1., 1., 1.], device='cuda:0'), 99: tensor([1., 1., 1.,  ..., 0., 0., 0.], device='cuda:0'), 102: tensor([1., 1., 1.,  ..., 0., 0., 0.], device='cuda:0')}

# %%
model = m.model

# %%
dict ={}


for key, value in model.state_dict().items():
    temp = []
    if len(value.shape) ==4:
        print('pruning channel and layer name : ',len(value),',', key)
        for i in range(len(value)):
            if value[i].sum() == 0: 
                print('pruning channex index : ', i)
                #temp = torch.norm(value.view(len(value), -1) , p= 1, dim=1)
                #print(temp)
                #dict[key].append(i)
                temp.append(i)
    if temp:   
        dict[key]  = temp
# Out:
# pruning channel and layer name :  24 , backbone.backbone.stem.conv.conv.weight
# pruning channel and layer name :  48 , backbone.backbone.dark2.0.conv.weight
# pruning channel and layer name :  24 , backbone.backbone.dark2.1.conv1.conv.weight
# pruning channel and layer name :  24 , backbone.backbone.dark2.1.conv2.conv.weight
# pruning channel and layer name :  48 , backbone.backbone.dark2.1.conv3.conv.weight
# pruning channel and layer name :  24 , backbone.backbone.dark2.1.m.0.conv1.conv.weight
# pruning channel and layer name :  24 , backbone.backbone.dark2.1.m.0.conv2.conv.weight
# pruning channel and layer name :  96 , backbone.backbone.dark3.0.conv.weight
# pruning channel and layer name :  36 , backbone.backbone.dark3.1.conv1.conv.weight
# pruning channex index :  3
# pruning channex index :  5
# pruning channex index :  12
# pruning channex index :  13
# pruning channex index :  14
# pruning channex index :  23
# pruning channex index :  25
# pruning channex index :  26
# pruning channex index :  30
# pruning channex index :  31
# pruning channex index :  32
# pruning channex index :  33
# pruning channel and layer name :  36 , backbone.backbone.dark3.1.conv2.conv.weight
# pruning channex index :  0
# pruning channex index :  1
# pruning channex index :  2
# pruning channex index :  3
# pruning channex index :  4
# pruning channex index :  6
# pruning channex index :  14
# pruning channex index :  16
# pruning channex index :  21
# pruning channex index :  28
# pruning channex index :  30
# pruning channex index :  34
# pruning channel and layer name :  72 , backbone.backbone.dark3.1.conv3.conv.weight
# pruning channel and layer name :  36 , backbone.backbone.dark3.1.m.0.conv1.conv.weight
# pruning channex index :  0
# pruning channex index :  3
# pruning channex index :  5
# pruning channex index :  6
# pruning channex index :  7
# pruning channex index :  13
# pruning channex index :  18
# pruning channex index :  20
# pruning channex index :  23
# pruning channex index :  27
# pruning channex index :  32
# pruning channex index :  33
# pruning channel and layer name :  36 , backbone.backbone.dark3.1.m.0.conv2.conv.weight
# pruning channel and layer name :  36 , backbone.backbone.dark3.1.m.1.conv1.conv.weight
# pruning channex index :  2
# pruning channex index :  3
# pruning channex index :  4
# pruning channex index :  8
# pruning channex index :  11
# pruning channex index :  17
# pruning channex index :  18
# pruning channex index :  20
# pruning channex index :  26
# pruning channex index :  30
# pruning channex index :  32
# pruning channex index :  33
# pruning channel and layer name :  36 , backbone.backbone.dark3.1.m.1.conv2.conv.weight
# pruning channel and layer name :  36 , backbone.backbone.dark3.1.m.2.conv1.conv.weight
# pruning channex index :  1
# pruning channex index :  4
# pruning channex index :  10
# pruning channex index :  12
# pruning channex index :  14
# pruning channex index :  16
# pruning channex index :  18
# pruning channex index :  24
# pruning channex index :  26
# pruning channex index :  28
# pruning channex index :  31
# pruning channex index :  34
# pruning channel and layer name :  36 , backbone.backbone.dark3.1.m.2.conv2.conv.weight
# pruning channel and layer name :  192 , backbone.backbone.dark4.0.conv.weight
# pruning channel and layer name :  72 , backbone.backbone.dark4.1.conv1.conv.weight
# pruning channex index :  4
# pruning channex index :  7
# pruning channex index :  11
# pruning channex index :  12
# pruning channex index :  13
# pruning channex index :  17
# pruning channex index :  19
# pruning channex index :  21
# pruning channex index :  23
# pruning channex index :  24
# pruning channex index :  26
# pruning channex index :  28
# pruning channex index :  32
# pruning channex index :  33
# pruning channex index :  34
# pruning channex index :  40
# pruning channex index :  42
# pruning channex index :  48
# pruning channex index :  52
# pruning channex index :  54
# pruning channex index :  56
# pruning channex index :  64
# pruning channex index :  67
# pruning channex index :  71
# pruning channel and layer name :  72 , backbone.backbone.dark4.1.conv2.conv.weight
# pruning channex index :  0
# pruning channex index :  3
# pruning channex index :  6
# pruning channex index :  11
# pruning channex index :  13
# pruning channex index :  14
# pruning channex index :  15
# pruning channex index :  18
# pruning channex index :  24
# pruning channex index :  26
# pruning channex index :  32
# pruning channex index :  40
# pruning channex index :  42
# pruning channex index :  43
# pruning channex index :  47
# pruning channex index :  49
# pruning channex index :  51
# pruning channex index :  55
# pruning channex index :  56
# pruning channex index :  58
# pruning channex index :  61
# pruning channex index :  63
# pruning channex index :  68
# pruning channex index :  69
# pruning channel and layer name :  144 , backbone.backbone.dark4.1.conv3.conv.weight
# pruning channel and layer name :  72 , backbone.backbone.dark4.1.m.0.conv1.conv.weight
# pruning channex index :  1
# pruning channex index :  2
# pruning channex index :  8
# pruning channex index :  12
# pruning channex index :  13
# pruning channex index :  16
# pruning channex index :  19
# pruning channex index :  20
# pruning channex index :  27
# pruning channex index :  28
# pruning channex index :  37
# pruning channex index :  44
# pruning channex index :  45
# pruning channex index :  49
# pruning channex index :  50
# pruning channex index :  51
# pruning channex index :  54
# pruning channex index :  60
# pruning channex index :  65
# pruning channex index :  66
# pruning channex index :  67
# pruning channex index :  68
# pruning channex index :  69
# pruning channex index :  71
# pruning channel and layer name :  72 , backbone.backbone.dark4.1.m.0.conv2.conv.weight
# pruning channel and layer name :  72 , backbone.backbone.dark4.1.m.1.conv1.conv.weight
# pruning channex index :  0
# pruning channex index :  3
# pruning channex index :  13
# pruning channex index :  16
# pruning channex index :  19
# pruning channex index :  21
# pruning channex index :  25
# pruning channex index :  30
# pruning channex index :  31
# pruning channex index :  32
# pruning channex index :  33
# pruning channex index :  36
# pruning channex index :  39
# pruning channex index :  40
# pruning channex index :  41
# pruning channex index :  42
# pruning channex index :  45
# pruning channex index :  51
# pruning channex index :  53
# pruning channex index :  58
# pruning channex index :  64
# pruning channex index :  65
# pruning channex index :  68
# pruning channex index :  70
# pruning channel and layer name :  72 , backbone.backbone.dark4.1.m.1.conv2.conv.weight
# pruning channel and layer name :  72 , backbone.backbone.dark4.1.m.2.conv1.conv.weight
# pruning channex index :  6
# pruning channex index :  9
# pruning channex index :  10
# pruning channex index :  12
# pruning channex index :  16
# pruning channex index :  17
# pruning channex index :  18
# pruning channex index :  20
# pruning channex index :  23
# pruning channex index :  24
# pruning channex index :  28
# pruning channex index :  30
# pruning channex index :  31
# pruning channex index :  33
# pruning channex index :  43
# pruning channex index :  44
# pruning channex index :  52
# pruning channex index :  56
# pruning channex index :  59
# pruning channex index :  62
# pruning channex index :  63
# pruning channex index :  64
# pruning channex index :  67
# pruning channex index :  71
# pruning channel and layer name :  72 , backbone.backbone.dark4.1.m.2.conv2.conv.weight
# pruning channel and layer name :  384 , backbone.backbone.dark5.0.conv.weight
# pruning channel and layer name :  192 , backbone.backbone.dark5.1.conv1.conv.weight
# pruning channel and layer name :  384 , backbone.backbone.dark5.1.conv2.conv.weight
# pruning channel and layer name :  144 , backbone.backbone.dark5.2.conv1.conv.weight
# pruning channex index :  1
# pruning channex index :  3
# pruning channex index :  6
# pruning channex index :  12
# pruning channex index :  20
# pruning channex index :  21
# pruning channex index :  24
# pruning channex index :  25
# pruning channex index :  28
# pruning channex index :  29
# pruning channex index :  30
# pruning channex index :  37
# pruning channex index :  40
# pruning channex index :  41
# pruning channex index :  43
# pruning channex index :  45
# pruning channex index :  49
# pruning channex index :  55
# pruning channex index :  57
# pruning channex index :  59
# pruning channex index :  60
# pruning channex index :  62
# pruning channex index :  64
# pruning channex index :  71
# pruning channex index :  72
# pruning channex index :  75
# pruning channex index :  78
# pruning channex index :  81
# pruning channex index :  83
# pruning channex index :  91
# pruning channex index :  92
# pruning channex index :  105
# pruning channex index :  106
# pruning channex index :  109
# pruning channex index :  112
# pruning channex index :  117
# pruning channex index :  118
# pruning channex index :  119
# pruning channex index :  120
# pruning channex index :  121
# pruning channex index :  122
# pruning channex index :  123
# pruning channex index :  124
# pruning channex index :  126
# pruning channex index :  135
# pruning channex index :  136
# pruning channex index :  138
# pruning channex index :  140
# pruning channel and layer name :  144 , backbone.backbone.dark5.2.conv2.conv.weight
# pruning channex index :  0
# pruning channex index :  3
# pruning channex index :  4
# pruning channex index :  5
# pruning channex index :  7
# pruning channex index :  8
# pruning channex index :  9
# pruning channex index :  10
# pruning channex index :  11
# pruning channex index :  16
# pruning channex index :  20
# pruning channex index :  21
# pruning channex index :  25
# pruning channex index :  26
# pruning channex index :  43
# pruning channex index :  44
# pruning channex index :  46
# pruning channex index :  47
# pruning channex index :  54
# pruning channex index :  59
# pruning channex index :  60
# pruning channex index :  65
# pruning channex index :  66
# pruning channex index :  67
# pruning channex index :  70
# pruning channex index :  74
# pruning channex index :  75
# pruning channex index :  78
# pruning channex index :  83
# pruning channex index :  85
# pruning channex index :  88
# pruning channex index :  89
# pruning channex index :  91
# pruning channex index :  94
# pruning channex index :  95
# pruning channex index :  100
# pruning channex index :  101
# pruning channex index :  102
# pruning channex index :  103
# pruning channex index :  104
# pruning channex index :  110
# pruning channex index :  111
# pruning channex index :  116
# pruning channex index :  119
# pruning channex index :  121
# pruning channex index :  122
# pruning channex index :  123
# pruning channex index :  134
# pruning channel and layer name :  288 , backbone.backbone.dark5.2.conv3.conv.weight
# pruning channel and layer name :  144 , backbone.backbone.dark5.2.m.0.conv1.conv.weight
# pruning channex index :  5
# pruning channex index :  6
# pruning channex index :  8
# pruning channex index :  11
# pruning channex index :  13
# pruning channex index :  15
# pruning channex index :  17
# pruning channex index :  19
# pruning channex index :  21
# pruning channex index :  24
# pruning channex index :  29
# pruning channex index :  34
# pruning channex index :  38
# pruning channex index :  39
# pruning channex index :  40
# pruning channex index :  41
# pruning channex index :  49
# pruning channex index :  50
# pruning channex index :  59
# pruning channex index :  65
# pruning channex index :  66
# pruning channex index :  67
# pruning channex index :  68
# pruning channex index :  71
# pruning channex index :  75
# pruning channex index :  76
# pruning channex index :  81
# pruning channex index :  82
# pruning channex index :  83
# pruning channex index :  90
# pruning channex index :  96
# pruning channex index :  98
# pruning channex index :  102
# pruning channex index :  103
# pruning channex index :  104
# pruning channex index :  105
# pruning channex index :  106
# pruning channex index :  110
# pruning channex index :  118
# pruning channex index :  120
# pruning channex index :  123
# pruning channex index :  129
# pruning channex index :  130
# pruning channex index :  135
# pruning channex index :  137
# pruning channex index :  139
# pruning channex index :  140
# pruning channex index :  143
# pruning channel and layer name :  144 , backbone.backbone.dark5.2.m.0.conv2.conv.weight
# pruning channex index :  2
# pruning channex index :  4
# pruning channex index :  8
# pruning channex index :  9
# pruning channex index :  11
# pruning channex index :  17
# pruning channex index :  18
# pruning channex index :  19
# pruning channex index :  22
# pruning channex index :  24
# pruning channex index :  26
# pruning channex index :  31
# pruning channex index :  37
# pruning channex index :  38
# pruning channex index :  39
# pruning channex index :  41
# pruning channex index :  42
# pruning channex index :  49
# pruning channex index :  50
# pruning channex index :  52
# pruning channex index :  55
# pruning channex index :  56
# pruning channex index :  57
# pruning channex index :  63
# pruning channex index :  71
# pruning channex index :  78
# pruning channex index :  81
# pruning channex index :  83
# pruning channex index :  84
# pruning channex index :  85
# pruning channex index :  88
# pruning channex index :  94
# pruning channex index :  101
# pruning channex index :  105
# pruning channex index :  106
# pruning channex index :  107
# pruning channex index :  109
# pruning channex index :  113
# pruning channex index :  114
# pruning channex index :  115
# pruning channex index :  119
# pruning channex index :  121
# pruning channex index :  124
# pruning channex index :  126
# pruning channex index :  129
# pruning channex index :  134
# pruning channex index :  142
# pruning channex index :  143
# pruning channel and layer name :  144 , backbone.lateral_conv0.conv.weight
# pruning channel and layer name :  72 , backbone.C3_p4.conv1.conv.weight
# pruning channel and layer name :  72 , backbone.C3_p4.conv2.conv.weight
# pruning channel and layer name :  144 , backbone.C3_p4.conv3.conv.weight
# pruning channel and layer name :  72 , backbone.C3_p4.m.0.conv1.conv.weight
# pruning channel and layer name :  72 , backbone.C3_p4.m.0.conv2.conv.weight
# pruning channel and layer name :  72 , backbone.reduce_conv1.conv.weight
# pruning channel and layer name :  36 , backbone.C3_p3.conv1.conv.weight
# pruning channel and layer name :  36 , backbone.C3_p3.conv2.conv.weight
# pruning channel and layer name :  72 , backbone.C3_p3.conv3.conv.weight
# pruning channel and layer name :  36 , backbone.C3_p3.m.0.conv1.conv.weight
# pruning channel and layer name :  36 , backbone.C3_p3.m.0.conv2.conv.weight
# pruning channel and layer name :  72 , backbone.bu_conv2.conv.weight
# pruning channel and layer name :  72 , backbone.C3_n3.conv1.conv.weight
# pruning channel and layer name :  72 , backbone.C3_n3.conv2.conv.weight
# pruning channel and layer name :  144 , backbone.C3_n3.conv3.conv.weight
# pruning channel and layer name :  72 , backbone.C3_n3.m.0.conv1.conv.weight
# pruning channel and layer name :  72 , backbone.C3_n3.m.0.conv2.conv.weight
# pruning channel and layer name :  144 , backbone.bu_conv1.conv.weight
# pruning channel and layer name :  144 , backbone.C3_n4.conv1.conv.weight
# pruning channel and layer name :  144 , backbone.C3_n4.conv2.conv.weight
# pruning channel and layer name :  288 , backbone.C3_n4.conv3.conv.weight
# pruning channel and layer name :  144 , backbone.C3_n4.m.0.conv1.conv.weight
# pruning channel and layer name :  144 , backbone.C3_n4.m.0.conv2.conv.weight
# pruning channel and layer name :  72 , head.cls_convs.0.0.conv.weight
# pruning channel and layer name :  96 , head.cls_convs.0.1.conv.weight
# pruning channel and layer name :  72 , head.cls_convs.1.0.conv.weight
# pruning channel and layer name :  96 , head.cls_convs.1.1.conv.weight
# pruning channel and layer name :  72 , head.cls_convs.2.0.conv.weight
# pruning channel and layer name :  96 , head.cls_convs.2.1.conv.weight
# pruning channel and layer name :  72 , head.reg_convs.0.0.conv.weight
# pruning channel and layer name :  96 , head.reg_convs.0.1.conv.weight
# pruning channel and layer name :  72 , head.reg_convs.1.0.conv.weight
# pruning channel and layer name :  96 , head.reg_convs.1.1.conv.weight
# pruning channel and layer name :  72 , head.reg_convs.2.0.conv.weight
# pruning channel and layer name :  96 , head.reg_convs.2.1.conv.weight
# pruning channel and layer name :  20 , head.cls_preds.0.weight
# pruning channel and layer name :  20 , head.cls_preds.1.weight
# pruning channel and layer name :  20 , head.cls_preds.2.weight
# pruning channel and layer name :  4 , head.reg_preds.0.weight
# pruning channel and layer name :  4 , head.reg_preds.1.weight
# pruning channel and layer name :  4 , head.reg_preds.2.weight
# pruning channel and layer name :  1 , head.obj_preds.0.weight
# pruning channel and layer name :  1 , head.obj_preds.1.weight
# pruning channel and layer name :  1 , head.obj_preds.2.weight
# pruning channel and layer name :  96 , head.stems.0.conv.weight
# pruning channel and layer name :  96 , head.stems.1.conv.weight
# pruning channel and layer name :  96 , head.stems.2.conv.weight

# %%
print(dict)
#del dict['backbone.backbone.dark3.1.conv3.conv.weight'][0]
# Out:
# {'backbone.backbone.dark3.1.conv1.conv.weight': [3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], 'backbone.backbone.dark3.1.conv2.conv.weight': [0, 1, 2, 3, 4, 6, 14, 16, 21, 28, 30, 34], 'backbone.backbone.dark3.1.m.0.conv1.conv.weight': [0, 3, 5, 6, 7, 13, 18, 20, 23, 27, 32, 33], 'backbone.backbone.dark3.1.m.1.conv1.conv.weight': [2, 3, 4, 8, 11, 17, 18, 20, 26, 30, 32, 33], 'backbone.backbone.dark3.1.m.2.conv1.conv.weight': [1, 4, 10, 12, 14, 16, 18, 24, 26, 28, 31, 34], 'backbone.backbone.dark4.1.conv1.conv.weight': [4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], 'backbone.backbone.dark4.1.conv2.conv.weight': [0, 3, 6, 11, 13, 14, 15, 18, 24, 26, 32, 40, 42, 43, 47, 49, 51, 55, 56, 58, 61, 63, 68, 69], 'backbone.backbone.dark4.1.m.0.conv1.conv.weight': [1, 2, 8, 12, 13, 16, 19, 20, 27, 28, 37, 44, 45, 49, 50, 51, 54, 60, 65, 66, 67, 68, 69, 71], 'backbone.backbone.dark4.1.m.1.conv1.conv.weight': [0, 3, 13, 16, 19, 21, 25, 30, 31, 32, 33, 36, 39, 40, 41, 42, 45, 51, 53, 58, 64, 65, 68, 70], 'backbone.backbone.dark4.1.m.2.conv1.conv.weight': [6, 9, 10, 12, 16, 17, 18, 20, 23, 24, 28, 30, 31, 33, 43, 44, 52, 56, 59, 62, 63, 64, 67, 71], 'backbone.backbone.dark5.2.conv1.conv.weight': [1, 3, 6, 12, 20, 21, 24, 25, 28, 29, 30, 37, 40, 41, 43, 45, 49, 55, 57, 59, 60, 62, 64, 71, 72, 75, 78, 81, 83, 91, 92, 105, 106, 109, 112, 117, 118, 119, 120, 121, 122, 123, 124, 126, 135, 136, 138, 140], 'backbone.backbone.dark5.2.conv2.conv.weight': [0, 3, 4, 5, 7, 8, 9, 10, 11, 16, 20, 21, 25, 26, 43, 44, 46, 47, 54, 59, 60, 65, 66, 67, 70, 74, 75, 78, 83, 85, 88, 89, 91, 94, 95, 100, 101, 102, 103, 104, 110, 111, 116, 119, 121, 122, 123, 134], 'backbone.backbone.dark5.2.m.0.conv1.conv.weight': [5, 6, 8, 11, 13, 15, 17, 19, 21, 24, 29, 34, 38, 39, 40, 41, 49, 50, 59, 65, 66, 67, 68, 71, 75, 76, 81, 82, 83, 90, 96, 98, 102, 103, 104, 105, 106, 110, 118, 120, 123, 129, 130, 135, 137, 139, 140, 143], 'backbone.backbone.dark5.2.m.0.conv2.conv.weight': [2, 4, 8, 9, 11, 17, 18, 19, 22, 24, 26, 31, 37, 38, 39, 41, 42, 49, 50, 52, 55, 56, 57, 63, 71, 78, 81, 83, 84, 85, 88, 94, 101, 105, 106, 107, 109, 113, 114, 115, 119, 121, 124, 126, 129, 134, 142, 143]}

# %%
temp = []
temp2 = list(dict.keys())
for i in range(len(temp2)):
        if 'bn' in temp2[i]:
            continue
        if 'weight' in temp2[i]:
            temp2[i] = temp2[i].replace('.weight','')
            temp2[i] = temp2[i].replace('2.0','2[0]')
            temp2[i] = temp2[i].replace('2.1','2[1]')
            temp2[i] = temp2[i].replace('3.0','3[0]')
            temp2[i] = temp2[i].replace('3.1','3[1]')
            temp2[i] = temp2[i].replace('4.0','4[0]')
            temp2[i] = temp2[i].replace('4.1','4[1]')
            temp2[i] = temp2[i].replace('5.0','5[0]')
            temp2[i] = temp2[i].replace('5.1','5[1]')
            temp2[i] = temp2[i].replace('5.2','5[2]')
            temp2[i] = temp2[i].replace('m.0','m[0]')
            temp2[i] = temp2[i].replace('m.1','m[1]')
            temp2[i] = temp2[i].replace('m.2','m[2]')
            temp.append(temp2[i])


import copy
key = []
temp2 = copy.deepcopy(temp)
for i in range(len(temp2)):
      
            temp2[i] = temp2[i].replace('[0][0]','.0.0')
            temp2[i] = temp2[i].replace('[0][1]','.0.1',)
            temp2[i] = temp2[i].replace('[1][0]','.1.0',)
            temp2[i] = temp2[i].replace('[1][1]','.1.1',)
            temp2[i] = temp2[i].replace('[2][0]','.2.0',)
            temp2[i] = temp2[i].replace('[2][1]','.2.1',)
            temp2[i] = temp2[i].replace('3[0]','3.0',)
            temp2[i] = temp2[i].replace('3[1]','3.1')
            temp2[i] = temp2[i].replace('4[0]','4.0',)
            temp2[i] = temp2[i].replace('4[1]','4.1',)
            temp2[i] = temp2[i].replace('5[0]','5.0',)
            temp2[i] = temp2[i].replace('5[1]','5.1',)
            temp2[i] = temp2[i].replace('5[2]','5.2',)
            temp2[i] = temp2[i].replace('m[0]','m.0',)
            temp2[i] = temp2[i].replace('m[1]','m.1',)
            temp2[i] = temp2[i].replace('m[2]','m.2',)
            temp2[i] = temp2[i].replace('[0]','.0',)
            temp2[i] = temp2[i].replace('[1]','.1',)
            temp2[i] = temp2[i].replace('[2]','.2',)
            key.append(temp2[i])

print(key)
print(temp)
# Out:
# ['backbone.backbone.dark3.1.conv1.conv', 'backbone.backbone.dark3.1.conv2.conv', 'backbone.backbone.dark3.1.m.0.conv1.conv', 'backbone.backbone.dark3.1.m.1.conv1.conv', 'backbone.backbone.dark3.1.m.2.conv1.conv', 'backbone.backbone.dark4.1.conv1.conv', 'backbone.backbone.dark4.1.conv2.conv', 'backbone.backbone.dark4.1.m.0.conv1.conv', 'backbone.backbone.dark4.1.m.1.conv1.conv', 'backbone.backbone.dark4.1.m.2.conv1.conv', 'backbone.backbone.dark5.2.conv1.conv', 'backbone.backbone.dark5.2.conv2.conv', 'backbone.backbone.dark5.2.m.0.conv1.conv', 'backbone.backbone.dark5.2.m.0.conv2.conv']
# ['backbone.backbone.dark3[1].conv1.conv', 'backbone.backbone.dark3[1].conv2.conv', 'backbone.backbone.dark3[1].m[0].conv1.conv', 'backbone.backbone.dark3[1].m[1].conv1.conv', 'backbone.backbone.dark3[1].m[2].conv1.conv', 'backbone.backbone.dark4[1].conv1.conv', 'backbone.backbone.dark4[1].conv2.conv', 'backbone.backbone.dark4[1].m[0].conv1.conv', 'backbone.backbone.dark4[1].m[1].conv1.conv', 'backbone.backbone.dark4[1].m[2].conv1.conv', 'backbone.backbone.dark5[2].conv1.conv', 'backbone.backbone.dark5[2].conv2.conv', 'backbone.backbone.dark5[2].m[0].conv1.conv', 'backbone.backbone.dark5[2].m[0].conv2.conv']

# %%
value = list(dict.values())
value
# Out:
# [[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33],
#  [0, 1, 2, 3, 4, 6, 14, 16, 21, 28, 30, 34],
#  [0, 3, 5, 6, 7, 13, 18, 20, 23, 27, 32, 33],
#  [2, 3, 4, 8, 11, 17, 18, 20, 26, 30, 32, 33],
#  [1, 4, 10, 12, 14, 16, 18, 24, 26, 28, 31, 34],
#  [4,
#   7,
#   11,
#   12,
#   13,
#   17,
#   19,
#   21,
#   23,
#   24,
#   26,
#   28,
#   32,
#   33,
#   34,
#   40,
#   42,
#   48,
#   52,
#   54,
#   56,
#   64,
#   67,
#   71],
#  [0,
#   3,
#   6,
#   11,
#   13,
#   14,
#   15,
#   18,
#   24,
#   26,
#   32,
#   40,
#   42,
#   43,
#   47,
#   49,
#   51,
#   55,
#   56,
#   58,
#   61,
#   63,
#   68,
#   69],
#  [1,
#   2,
#   8,
#   12,
#   13,
#   16,
#   19,
#   20,
#   27,
#   28,
#   37,
#   44,
#   45,
#   49,
#   50,
#   51,
#   54,
#   60,
#   65,
#   66,
#   67,
#   68,
#   69,
#   71],
#  [0,
#   3,
#   13,
#   16,
#   19,
#   21,
#   25,
#   30,
#   31,
#   32,
#   33,
#   36,
#   39,
#   40,
#   41,
#   42,
#   45,
#   51,
#   53,
#   58,
#   64,
#   65,
#   68,
#   70],
#  [6,
#   9,
#   10,
#   12,
#   16,
#   17,
#   18,
#   20,
#   23,
#   24,
#   28,
#   30,
#   31,
#   33,
#   43,
#   44,
#   52,
#   56,
#   59,
#   62,
#   63,
#   64,
#   67,
#   71],
#  [1,
#   3,
#   6,
#   12,
#   20,
#   21,
#   24,
#   25,
#   28,
#   29,
#   30,
#   37,
#   40,
#   41,
#   43,
#   45,
#   49,
#   55,
#   57,
#   59,
#   60,
#   62,
#   64,
#   71,
#   72,
#   75,
#   78,
#   81,
#   83,
#   91,
#   92,
#   105,
#   106,
#   109,
#   112,
#   117,
#   118,
#   119,
#   120,
#   121,
#   122,
#   123,
#   124,
#   126,
#   135,
#   136,
#   138,
#   140],
#  [0,
#   3,
#   4,
#   5,
#   7,
#   8,
#   9,
#   10,
#   11,
#   16,
#   20,
#   21,
#   25,
#   26,
#   43,
#   44,
#   46,
#   47,
#   54,
#   59,
#   60,
#   65,
#   66,
#   67,
#   70,
#   74,
#   75,
#   78,
#   83,
#   85,
#   88,
#   89,
#   91,
#   94,
#   95,
#   100,
#   101,
#   102,
#   103,
#   104,
#   110,
#   111,
#   116,
#   119,
#   121,
#   122,
#   123,
#   134],
#  [5,
#   6,
#   8,
#   11,
#   13,
#   15,
#   17,
#   19,
#   21,
#   24,
#   29,
#   34,
#   38,
#   39,
#   40,
#   41,
#   49,
#   50,
#   59,
#   65,
#   66,
#   67,
#   68,
#   71,
#   75,
#   76,
#   81,
#   82,
#   83,
#   90,
#   96,
#   98,
#   102,
#   103,
#   104,
#   105,
#   106,
#   110,
#   118,
#   120,
#   123,
#   129,
#   130,
#   135,
#   137,
#   139,
#   140,
#   143],
#  [2,
#   4,
#   8,
#   9,
#   11,
#   17,
#   18,
#   19,
#   22,
#   24,
#   26,
#   31,
#   37,
#   38,
#   39,
#   41,
#   42,
#   49,
#   50,
#   52,
#   55,
#   56,
#   57,
#   63,
#   71,
#   78,
#   81,
#   83,
#   84,
#   85,
#   88,
#   94,
#   101,
#   105,
#   106,
#   107,
#   109,
#   113,
#   114,
#   115,
#   119,
#   121,
#   124,
#   126,
#   129,
#   134,
#   142,
#   143]]

# %%
for i in range(len(temp)):
    #pruning_plan = DG.get_pruning_plan(eval(f"model.{temp[i]}"), tp.prune_conv_out_channel, value[i])
    pruning_plan = DG.get_pruning_plan(eval(f"model.{temp[i]}"), tp.prune_conv_out_channel, dict[(key[i]) + '.weight'])
    print(pruning_plan)
    if DG.check_pruning_plan(pruning_plan):
        pruning_plan.exec()
# Out:
# Conv2d(96, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv1.conv (Conv2d(96, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.conv1.conv (Conv2d(96, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={'#params': 1152}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv1.conv (Conv2d(96, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.conv1.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={'#params': 24}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.conv1.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.0.conv1.conv (Conv2d(36, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={'#params': 432}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.1.conv1.conv (Conv2d(36, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={'#params': 432}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.2.conv1.conv (Conv2d(36, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={'#params': 432}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConcatPruner on _ConcatOp([0, 36, 72]), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 36, 72]) => ConvInChannelPruner on backbone.backbone.dark3.1.conv3.conv (Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={'#params': 864}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark3.1.m.2.conv2.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={'#params': 24}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.2.conv2.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.2.conv2.conv (Conv2d(36, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={'#params': 3888}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark3.1.m.1.conv2.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={'#params': 24}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.1.conv2.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.1.conv2.conv (Conv2d(36, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={'#params': 3888}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark3.1.m.0.conv2.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={'#params': 24}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.0.conv2.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.0.conv2.conv (Conv2d(36, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[3, 5, 12, 13, 14, 23, 25, 26, 30, 31, 32, 33], metric={'#params': 3888}]
#
# Metric Sum: {'#params': 15072}
# --------------------------------
#
# Conv2d(96, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv2.conv (Conv2d(96, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.conv2.conv (Conv2d(96, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 1, 2, 3, 4, 6, 14, 16, 21, 28, 30, 34], metric={'#params': 1152}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.conv2.conv (Conv2d(96, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.conv2.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 1, 2, 3, 4, 6, 14, 16, 21, 28, 30, 34], metric={'#params': 24}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.conv2.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 1, 2, 3, 4, 6, 14, 16, 21, 28, 30, 34], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 24, 60]), Index=[24, 25, 26, 27, 28, 30, 38, 40, 45, 52, 54, 58], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 24, 60]) => ConvInChannelPruner on backbone.backbone.dark3.1.conv3.conv (Conv2d(60, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[24, 25, 26, 27, 28, 30, 38, 40, 45, 52, 54, 58], metric={'#params': 864}]
#
# Metric Sum: {'#params': 2040}
# --------------------------------
#
# Conv2d(24, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.0.conv1.conv (Conv2d(24, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.0.conv1.conv (Conv2d(24, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 3, 5, 6, 7, 13, 18, 20, 23, 27, 32, 33], metric={'#params': 288}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.0.conv1.conv (Conv2d(24, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.m.0.conv1.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 3, 5, 6, 7, 13, 18, 20, 23, 27, 32, 33], metric={'#params': 24}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.0.conv1.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 3, 5, 6, 7, 13, 18, 20, 23, 27, 32, 33], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.0.conv2.conv (Conv2d(36, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[0, 3, 5, 6, 7, 13, 18, 20, 23, 27, 32, 33], metric={'#params': 2592}]
#
# Metric Sum: {'#params': 2904}
# --------------------------------
#
# Conv2d(24, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.1.conv1.conv (Conv2d(24, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.1.conv1.conv (Conv2d(24, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[2, 3, 4, 8, 11, 17, 18, 20, 26, 30, 32, 33], metric={'#params': 288}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.1.conv1.conv (Conv2d(24, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.m.1.conv1.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[2, 3, 4, 8, 11, 17, 18, 20, 26, 30, 32, 33], metric={'#params': 24}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.1.conv1.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[2, 3, 4, 8, 11, 17, 18, 20, 26, 30, 32, 33], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.1.conv2.conv (Conv2d(36, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[2, 3, 4, 8, 11, 17, 18, 20, 26, 30, 32, 33], metric={'#params': 2592}]
#
# Metric Sum: {'#params': 2904}
# --------------------------------
#
# Conv2d(24, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.2.conv1.conv (Conv2d(24, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark3.1.m.2.conv1.conv (Conv2d(24, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 4, 10, 12, 14, 16, 18, 24, 26, 28, 31, 34], metric={'#params': 288}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark3.1.m.2.conv1.conv (Conv2d(24, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark3.1.m.2.conv1.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 4, 10, 12, 14, 16, 18, 24, 26, 28, 31, 34], metric={'#params': 24}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark3.1.m.2.conv1.bn (BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 4, 10, 12, 14, 16, 18, 24, 26, 28, 31, 34], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark3.1.m.2.conv2.conv (Conv2d(36, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[1, 4, 10, 12, 14, 16, 18, 24, 26, 28, 31, 34], metric={'#params': 2592}]
#
# Metric Sum: {'#params': 2904}
# --------------------------------
#
# Conv2d(192, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv1.conv (Conv2d(192, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.conv1.conv (Conv2d(192, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={'#params': 4608}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv1.conv (Conv2d(192, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.conv1.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={'#params': 48}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.conv1.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.0.conv1.conv (Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={'#params': 1728}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.1.conv1.conv (Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={'#params': 1728}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(AddBackward0), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.2.conv1.conv (Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={'#params': 1728}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(AddBackward0) => ConcatPruner on _ConcatOp([0, 72, 144]), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 72, 144]) => ConvInChannelPruner on backbone.backbone.dark4.1.conv3.conv (Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={'#params': 3456}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark4.1.m.2.conv2.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={'#params': 48}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.2.conv2.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.2.conv2.conv (Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={'#params': 15552}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark4.1.m.1.conv2.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={'#params': 48}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.1.conv2.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.1.conv2.conv (Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={'#params': 15552}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => BatchnormPruner on backbone.backbone.dark4.1.m.0.conv2.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={'#params': 48}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.0.conv2.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.0.conv2.conv (Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[4, 7, 11, 12, 13, 17, 19, 21, 23, 24, 26, 28, 32, 33, 34, 40, 42, 48, 52, 54, 56, 64, 67, 71], metric={'#params': 15552}]
#
# Metric Sum: {'#params': 60096}
# --------------------------------
#
# Conv2d(192, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv2.conv (Conv2d(192, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.conv2.conv (Conv2d(192, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 3, 6, 11, 13, 14, 15, 18, 24, 26, 32, 40, 42, 43, 47, 49, 51, 55, 56, 58, 61, 63, 68, 69], metric={'#params': 4608}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.conv2.conv (Conv2d(192, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.conv2.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 3, 6, 11, 13, 14, 15, 18, 24, 26, 32, 40, 42, 43, 47, 49, 51, 55, 56, 58, 61, 63, 68, 69], metric={'#params': 48}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.conv2.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 3, 6, 11, 13, 14, 15, 18, 24, 26, 32, 40, 42, 43, 47, 49, 51, 55, 56, 58, 61, 63, 68, 69], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 48, 120]), Index=[48, 51, 54, 59, 61, 62, 63, 66, 72, 74, 80, 88, 90, 91, 95, 97, 99, 103, 104, 106, 109, 111, 116, 117], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 48, 120]) => ConvInChannelPruner on backbone.backbone.dark4.1.conv3.conv (Conv2d(120, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[48, 51, 54, 59, 61, 62, 63, 66, 72, 74, 80, 88, 90, 91, 95, 97, 99, 103, 104, 106, 109, 111, 116, 117], metric={'#params': 3456}]
#
# Metric Sum: {'#params': 8112}
# --------------------------------
#
# Conv2d(48, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.0.conv1.conv (Conv2d(48, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.0.conv1.conv (Conv2d(48, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 2, 8, 12, 13, 16, 19, 20, 27, 28, 37, 44, 45, 49, 50, 51, 54, 60, 65, 66, 67, 68, 69, 71], metric={'#params': 1152}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.0.conv1.conv (Conv2d(48, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.m.0.conv1.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 2, 8, 12, 13, 16, 19, 20, 27, 28, 37, 44, 45, 49, 50, 51, 54, 60, 65, 66, 67, 68, 69, 71], metric={'#params': 48}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.0.conv1.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 2, 8, 12, 13, 16, 19, 20, 27, 28, 37, 44, 45, 49, 50, 51, 54, 60, 65, 66, 67, 68, 69, 71], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.0.conv2.conv (Conv2d(72, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[1, 2, 8, 12, 13, 16, 19, 20, 27, 28, 37, 44, 45, 49, 50, 51, 54, 60, 65, 66, 67, 68, 69, 71], metric={'#params': 10368}]
#
# Metric Sum: {'#params': 11568}
# --------------------------------
#
# Conv2d(48, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.1.conv1.conv (Conv2d(48, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.1.conv1.conv (Conv2d(48, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 3, 13, 16, 19, 21, 25, 30, 31, 32, 33, 36, 39, 40, 41, 42, 45, 51, 53, 58, 64, 65, 68, 70], metric={'#params': 1152}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.1.conv1.conv (Conv2d(48, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.m.1.conv1.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 3, 13, 16, 19, 21, 25, 30, 31, 32, 33, 36, 39, 40, 41, 42, 45, 51, 53, 58, 64, 65, 68, 70], metric={'#params': 48}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.1.conv1.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 3, 13, 16, 19, 21, 25, 30, 31, 32, 33, 36, 39, 40, 41, 42, 45, 51, 53, 58, 64, 65, 68, 70], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.1.conv2.conv (Conv2d(72, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[0, 3, 13, 16, 19, 21, 25, 30, 31, 32, 33, 36, 39, 40, 41, 42, 45, 51, 53, 58, 64, 65, 68, 70], metric={'#params': 10368}]
#
# Metric Sum: {'#params': 11568}
# --------------------------------
#
# Conv2d(48, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.2.conv1.conv (Conv2d(48, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark4.1.m.2.conv1.conv (Conv2d(48, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[6, 9, 10, 12, 16, 17, 18, 20, 23, 24, 28, 30, 31, 33, 43, 44, 52, 56, 59, 62, 63, 64, 67, 71], metric={'#params': 1152}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark4.1.m.2.conv1.conv (Conv2d(48, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark4.1.m.2.conv1.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[6, 9, 10, 12, 16, 17, 18, 20, 23, 24, 28, 30, 31, 33, 43, 44, 52, 56, 59, 62, 63, 64, 67, 71], metric={'#params': 48}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark4.1.m.2.conv1.bn (BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[6, 9, 10, 12, 16, 17, 18, 20, 23, 24, 28, 30, 31, 33, 43, 44, 52, 56, 59, 62, 63, 64, 67, 71], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark4.1.m.2.conv2.conv (Conv2d(72, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[6, 9, 10, 12, 16, 17, 18, 20, 23, 24, 28, 30, 31, 33, 43, 44, 52, 56, 59, 62, 63, 64, 67, 71], metric={'#params': 10368}]
#
# Metric Sum: {'#params': 11568}
# --------------------------------
#
# Conv2d(384, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv1.conv (Conv2d(384, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark5.2.conv1.conv (Conv2d(384, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 3, 6, 12, 20, 21, 24, 25, 28, 29, 30, 37, 40, 41, 43, 45, 49, 55, 57, 59, 60, 62, 64, 71, 72, 75, 78, 81, 83, 91, 92, 105, 106, 109, 112, 117, 118, 119, 120, 121, 122, 123, 124, 126, 135, 136, 138, 140], metric={'#params': 18432}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv1.conv (Conv2d(384, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark5.2.conv1.bn (BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[1, 3, 6, 12, 20, 21, 24, 25, 28, 29, 30, 37, 40, 41, 43, 45, 49, 55, 57, 59, 60, 62, 64, 71, 72, 75, 78, 81, 83, 91, 92, 105, 106, 109, 112, 117, 118, 119, 120, 121, 122, 123, 124, 126, 135, 136, 138, 140], metric={'#params': 96}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark5.2.conv1.bn (BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[1, 3, 6, 12, 20, 21, 24, 25, 28, 29, 30, 37, 40, 41, 43, 45, 49, 55, 57, 59, 60, 62, 64, 71, 72, 75, 78, 81, 83, 91, 92, 105, 106, 109, 112, 117, 118, 119, 120, 121, 122, 123, 124, 126, 135, 136, 138, 140], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark5.2.m.0.conv1.conv (Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[1, 3, 6, 12, 20, 21, 24, 25, 28, 29, 30, 37, 40, 41, 43, 45, 49, 55, 57, 59, 60, 62, 64, 71, 72, 75, 78, 81, 83, 91, 92, 105, 106, 109, 112, 117, 118, 119, 120, 121, 122, 123, 124, 126, 135, 136, 138, 140], metric={'#params': 6912}]
#
# Metric Sum: {'#params': 25440}
# --------------------------------
#
# Conv2d(384, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv2.conv (Conv2d(384, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark5.2.conv2.conv (Conv2d(384, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[0, 3, 4, 5, 7, 8, 9, 10, 11, 16, 20, 21, 25, 26, 43, 44, 46, 47, 54, 59, 60, 65, 66, 67, 70, 74, 75, 78, 83, 85, 88, 89, 91, 94, 95, 100, 101, 102, 103, 104, 110, 111, 116, 119, 121, 122, 123, 134], metric={'#params': 18432}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.conv2.conv (Conv2d(384, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark5.2.conv2.bn (BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[0, 3, 4, 5, 7, 8, 9, 10, 11, 16, 20, 21, 25, 26, 43, 44, 46, 47, 54, 59, 60, 65, 66, 67, 70, 74, 75, 78, 83, 85, 88, 89, 91, 94, 95, 100, 101, 102, 103, 104, 110, 111, 116, 119, 121, 122, 123, 134], metric={'#params': 96}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark5.2.conv2.bn (BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[0, 3, 4, 5, 7, 8, 9, 10, 11, 16, 20, 21, 25, 26, 43, 44, 46, 47, 54, 59, 60, 65, 66, 67, 70, 74, 75, 78, 83, 85, 88, 89, 91, 94, 95, 100, 101, 102, 103, 104, 110, 111, 116, 119, 121, 122, 123, 134], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 144, 288]), Index=[144, 147, 148, 149, 151, 152, 153, 154, 155, 160, 164, 165, 169, 170, 187, 188, 190, 191, 198, 203, 204, 209, 210, 211, 214, 218, 219, 222, 227, 229, 232, 233, 235, 238, 239, 244, 245, 246, 247, 248, 254, 255, 260, 263, 265, 266, 267, 278], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 144, 288]) => ConvInChannelPruner on backbone.backbone.dark5.2.conv3.conv (Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[144, 147, 148, 149, 151, 152, 153, 154, 155, 160, 164, 165, 169, 170, 187, 188, 190, 191, 198, 203, 204, 209, 210, 211, 214, 218, 219, 222, 227, 229, 232, 233, 235, 238, 239, 244, 245, 246, 247, 248, 254, 255, 260, 263, 265, 266, 267, 278], metric={'#params': 13824}]
#
# Metric Sum: {'#params': 32352}
# --------------------------------
#
# Conv2d(96, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv1.conv (Conv2d(96, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv1.conv (Conv2d(96, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[5, 6, 8, 11, 13, 15, 17, 19, 21, 24, 29, 34, 38, 39, 40, 41, 49, 50, 59, 65, 66, 67, 68, 71, 75, 76, 81, 82, 83, 90, 96, 98, 102, 103, 104, 105, 106, 110, 118, 120, 123, 129, 130, 135, 137, 139, 140, 143], metric={'#params': 4608}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv1.conv (Conv2d(96, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark5.2.m.0.conv1.bn (BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[5, 6, 8, 11, 13, 15, 17, 19, 21, 24, 29, 34, 38, 39, 40, 41, 49, 50, 59, 65, 66, 67, 68, 71, 75, 76, 81, 82, 83, 90, 96, 98, 102, 103, 104, 105, 106, 110, 118, 120, 123, 129, 130, 135, 137, 139, 140, 143], metric={'#params': 96}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark5.2.m.0.conv1.bn (BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[5, 6, 8, 11, 13, 15, 17, 19, 21, 24, 29, 34, 38, 39, 40, 41, 49, 50, 59, 65, 66, 67, 68, 71, 75, 76, 81, 82, 83, 90, 96, 98, 102, 103, 104, 105, 106, 110, 118, 120, 123, 129, 130, 135, 137, 139, 140, 143], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConvInChannelPruner on backbone.backbone.dark5.2.m.0.conv2.conv (Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[5, 6, 8, 11, 13, 15, 17, 19, 21, 24, 29, 34, 38, 39, 40, 41, 49, 50, 59, 65, 66, 67, 68, 71, 75, 76, 81, 82, 83, 90, 96, 98, 102, 103, 104, 105, 106, 110, 118, 120, 123, 129, 130, 135, 137, 139, 140, 143], metric={'#params': 62208}]
#
# Metric Sum: {'#params': 66912}
# --------------------------------
#
# Conv2d(96, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#
# --------------------------------
#           Pruning Plan
# --------------------------------
# User pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv2.conv (Conv2d(96, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv2.conv (Conv2d(96, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), Index=[2, 4, 8, 9, 11, 17, 18, 19, 22, 24, 26, 31, 37, 38, 39, 41, 42, 49, 50, 52, 55, 56, 57, 63, 71, 78, 81, 83, 84, 85, 88, 94, 101, 105, 106, 107, 109, 113, 114, 115, 119, 121, 124, 126, 129, 134, 142, 143], metric={'#params': 41472}]
#
# Coupled pruning:
# [ [DEP] ConvOutChannelPruner on backbone.backbone.dark5.2.m.0.conv2.conv (Conv2d(96, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => BatchnormPruner on backbone.backbone.dark5.2.m.0.conv2.bn (BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)), Index=[2, 4, 8, 9, 11, 17, 18, 19, 22, 24, 26, 31, 37, 38, 39, 41, 42, 49, 50, 52, 55, 56, 57, 63, 71, 78, 81, 83, 84, 85, 88, 94, 101, 105, 106, 107, 109, 113, 114, 115, 119, 121, 124, 126, 129, 134, 142, 143], metric={'#params': 96}]
# [ [DEP] BatchnormPruner on backbone.backbone.dark5.2.m.0.conv2.bn (BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)) => ElementWiseOpPruner on _ElementWiseOp(SiluBackward0), Index=[2, 4, 8, 9, 11, 17, 18, 19, 22, 24, 26, 31, 37, 38, 39, 41, 42, 49, 50, 52, 55, 56, 57, 63, 71, 78, 81, 83, 84, 85, 88, 94, 101, 105, 106, 107, 109, 113, 114, 115, 119, 121, 124, 126, 129, 134, 142, 143], metric={}]
# [ [DEP] ElementWiseOpPruner on _ElementWiseOp(SiluBackward0) => ConcatPruner on _ConcatOp([0, 144, 240]), Index=[2, 4, 8, 9, 11, 17, 18, 19, 22, 24, 26, 31, 37, 38, 39, 41, 42, 49, 50, 52, 55, 56, 57, 63, 71, 78, 81, 83, 84, 85, 88, 94, 101, 105, 106, 107, 109, 113, 114, 115, 119, 121, 124, 126, 129, 134, 142, 143], metric={}]
# [ [DEP] ConcatPruner on _ConcatOp([0, 144, 240]) => ConvInChannelPruner on backbone.backbone.dark5.2.conv3.conv (Conv2d(240, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)), Index=[2, 4, 8, 9, 11, 17, 18, 19, 22, 24, 26, 31, 37, 38, 39, 41, 42, 49, 50, 52, 55, 56, 57, 63, 71, 78, 81, 83, 84, 85, 88, 94, 101, 105, 106, 107, 109, 113, 114, 115, 119, 121, 124, 126, 129, 134, 142, 143], metric={'#params': 13824}]
#
# Metric Sum: {'#params': 55392}
# --------------------------------

# %%
print(model)
# Out:
# YOLOX(
#   (backbone): YOLOPAFPN(
#     (backbone): CSPDarknet(
#       (stem): Focus(
#         (conv): BaseConv(
#           (conv): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (dark2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(24, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark3): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(48, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(48, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(24, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark4): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(72, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(96, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark5): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(144, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): SPPBottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): ModuleList(
#             (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#             (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#             (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(192, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(288, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (upsample): Upsample(scale_factor=2.0, mode=nearest)
#     (lateral_conv0): BaseConv(
#       (conv): Conv2d(288, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (reduce_conv1): BaseConv(
#       (conv): Conv2d(144, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(36, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(36, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(36, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv2): BaseConv(
#       (conv): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(144, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(144, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv1): BaseConv(
#       (conv): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(288, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(288, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(144, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (head): YOLOXHead(
#     (cls_convs): ModuleList(
#       (0): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(72, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(72, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(72, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (reg_convs): ModuleList(
#       (0): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(72, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(72, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(96, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(72, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(72, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (cls_preds): ModuleList(
#       (0): Conv2d(96, 20, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 20, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 20, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (reg_preds): ModuleList(
#       (0): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (obj_preds): ModuleList(
#       (0): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stems): ModuleList(
#       (0): BaseConv(
#         (conv): Conv2d(72, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): BaseConv(
#         (conv): Conv2d(144, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): BaseConv(
#         (conv): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (l1_loss): L1Loss()
#     (bcewithlog_loss): BCEWithLogitsLoss()
#     (iou_loss): IOUloss()
#   )
# )

# %%
ckpt_state = {
                "model": model.state_dict(),
            }

torch.save(ckpt_state, 'type3_b_50_0.25_a_v2.pth')
